# %%
import torch
torch.cuda.is_available()#pregunta si hay una gpu disponible
# Out:
# True

# %% [markdown]
# ## Entrenamiento con HTS-AT para clasificar sonidos
#
# <!-- Referece:
#
# [HTS-AT: A Hierarchical Token-Semantic Audio Transformer for Sound Classification and Detection, ICASSP 2022](https://arxiv.org/abs/2202.00874)
#
# Following the HTS-AT's paper, in this tutorial, we would show how to use the HST-AT in the training of the ESC-50 Dataset.
#
# The [ESC-50 dataset](https://github.com/karolpiczak/ESC-50) is a labeled collection of 2000 environmental audio recordings suitable for benchmarking methods of environmental sound classification. The dataset consists of 5-second-long recordings organized into 50 semantical classes (with 40 examples per class) loosely arranged into 5 major categories
#
# Before running this tutorial, please make sure that you install the below packages by following steps:
#
# 1. download [the codebase](https://github.com/RetroCirce/HTS-Audio-Transformer), and put this tutorial notebook inside the codebase folder.
#
# 2. In the github code folder:
#
#     > pip install -r requirements.txt
#
# 3. We do not include the installation of PyTorch in the requirment, since different machines require different vereions of CUDA and Toolkits. So make sure you install the PyTorch from [the official guidance](https://pytorch.org/).
#
# 4. Install the 'SOX' and the 'ffmpeg', we recommend that you run this code in Linux inside the Conda environment. In that, you can install them by:
#
#     > sudo apt install sox
#
#     > conda install -c conda-forge ffmpeg -->

# %%
# import basic packages
import os
import numpy as np
import wget
import sys
import gdown
import zipfile
import librosa
import subprocess
# in the notebook, we only can use one GPU
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# Build the workspace and download the needed files

def create_path(path):
    if not os.path.exists(path):
        os.mkdir(path)

workspace = 'D:\\SEMESTRE 2-2023\\INTELIGENCIA ARTIFICIAL 3 - SIS330\\modelos_deteccion_sonidos\\HTS-Audio-Transformer\\workspace'
dataset_path = os.path.join(workspace, "dataset_sonidos_peligrosos")
checkpoint_path = os.path.join(workspace, "ckpt")
esc_raw_path = os.path.join(dataset_path, 'raw')


create_path(workspace)
create_path(dataset_path)
create_path(checkpoint_path)
create_path(esc_raw_path)

# Descargamos los pesos pre-entrenados para el modelo
if not os.path.exists(os.path.join(checkpoint_path,'htsat_audioset_pretrain.ckpt')):
    gdown.download(id='1OK8a5XuMVLyeVKF117L8pfxeZYdfSDZv', output=os.path.join(checkpoint_path,'htsat_audioset_pretrain.ckpt'))

# %%
sox_path = 'C:\\Program Files (x86)\\sox-14-4-2\\sox.exe'  # Asegúrate de que esta ruta sea correcta

# %%
# Preprocesamiento de los datos
meta_path = os.path.join(esc_raw_path, 'sonidos_peligrosos', 'meta', 'dataset_sonidos_peligrosos_recortado.csv')
audio_path = os.path.join(esc_raw_path, 'sonidos_peligrosos', 'audio')
resample_path = os.path.join(dataset_path, 'resample_sonidos_peligrosos')
savedata_path = os.path.join(dataset_path, 'sonidos_peligrosos-data.npy')
create_path(resample_path)

meta = np.loadtxt(meta_path , delimiter=',', dtype='str', skiprows=1)
audio_list = os.listdir(audio_path)

# resample
print("-------------Resample dataset_sonidos_peligrosos-------------")
for f in audio_list:
    full_f = os.path.join(audio_path, f)
    resample_f = os.path.join(resample_path, f)
    
    if not os.path.exists(resample_f):
        command = [sox_path, '-V1', full_f, '-r', '32000', resample_f]
        result = subprocess.run(command, capture_output=True, text=True)
        if result.returncode != 0:
            print(f"Error resampling {f}: {result.stderr}")
        else:
            print(f"Resampled {f} successfully.")

print("-------------Success-------------")

print("-------------Build Dataset-------------")

output_dict = [[] for _ in range(5)]
for label in meta:
    name = label[0]
    fold = int(float(label[1]))
    target = label[2]
    y, sr = librosa.load(os.path.join(resample_path, name), sr = None)
    output_dict[int(fold) - 1].append(
        {
            "name": name,
            "target": int(float(target)),
            "waveform": y
        }
    )
np.save(savedata_path, output_dict)
print("-------------Success-------------")
# Out:
# -------------Resample dataset_sonidos_peligrosos-------------
# Resampled 1-102121-A-6.wav successfully.
# Resampled 1-102955-A-1.wav successfully.
# Resampled 1-103015-A-3.wav successfully.
# Resampled 1-108676-A-5.wav successfully.
# Resampled 1-109272-A-5.wav successfully.
# Resampled 1-109543-A-4.wav successfully.
# Resampled 1-110814-A-6.wav successfully.
# Resampled 1-115200-A-6.wav successfully.
# Resampled 1-120097-A-3.wav successfully.
# Resampled 1-120866-A-5.wav successfully.
# Resampled 1-125273-A-5.wav successfully.
# Resampled 1-12566-A-2.wav successfully.
# Resampled 1-127347-A-9.wav successfully.
# Resampled 1-12739-A-0.wav successfully.
# Resampled 1-128378-A-4.wav successfully.
# Resampled 1-132413-A-9.wav successfully.
# Resampled 1-133063-A-6.wav successfully.
# Resampled 1-133529-A-7.wav successfully.
# Resampled 1-133845-A-6.wav successfully.
# Resampled 1-135068-A-1.wav successfully.
# Resampled 1-1359-A-5.wav successfully.
# Resampled 1-136190-A-8.wav successfully.
# Resampled 1-138565-A-5.wav successfully.
# Resampled 1-143560-A-0.wav successfully.
# Resampled 1-144204-A-5.wav successfully.
# Resampled 1-147834-A-3.wav successfully.
# Resampled 1-149949-A-8.wav successfully.
# Resampled 1-151690-A-9.wav successfully.
# Resampled 1-152065-A-0.wav successfully.
# Resampled 1-152121-A-7.wav successfully.
# Resampled 1-152611-A-2.wav successfully.
# Resampled 1-1554-A-1.wav successfully.
# Resampled 1-155544-A-3.wav successfully.
# Resampled 1-157615-A-0.wav successfully.
# Resampled 1-160055-A-0.wav successfully.
# Resampled 1-161475-A-5.wav successfully.
# Resampled 1-162660-A-3.wav successfully.
# Resampled 1-165932-A-3.wav successfully.
# Resampled 1-169708-A-0.wav successfully.
# Resampled 1-17069-A-9.wav successfully.
# Resampled 1-172728-A-9.wav successfully.
# Resampled 1-176039-A-6.wav successfully.
# Resampled 1-17736-A-2.wav successfully.
# Resampled 1-178384-A-4.wav successfully.
# Resampled 1-180241-A-7.wav successfully.
# Resampled 1-182740-A-8.wav successfully.
# Resampled 1-183162-A-1.wav successfully.
# Resampled 1-184331-A-9.wav successfully.
# Resampled 1-188660-A-4.wav successfully.
# Resampled 1-194396-A-7.wav successfully.
# Resampled 1-199573-A-6.wav successfully.
# Resampled 1-204680-A-0.wav successfully.
# Resampled 1-205590-A-8.wav successfully.
# Resampled 1-210183-A-2.wav successfully.
# Resampled 1-213190-A-6.wav successfully.
# Resampled 1-213955-A-7.wav successfully.
# Resampled 1-220605-A-4.wav successfully.
# Resampled 1-224155-A-8.wav successfully.
# Resampled 1-224547-A-9.wav successfully.
# Resampled 1-225758-A-6.wav successfully.
# Resampled 1-22758-A-7.wav successfully.
# Resampled 1-228859-A-1.wav successfully.
# Resampled 1-230452-A-4.wav successfully.
# Resampled 1-232259-A-5.wav successfully.
# Resampled 1-236611-A-5.wav successfully.
# Resampled 1-2373-A-1.wav successfully.
# Resampled 1-238455-A-1.wav successfully.
# Resampled 1-23893-A-7.wav successfully.
# Resampled 1-239902-A-6.wav successfully.
# Resampled 1-242055-A-7.wav successfully.
# Resampled 1-242694-A-1.wav successfully.
# Resampled 1-243140-A-7.wav successfully.
# Resampled 1-243568-A-6.wav successfully.
# Resampled 1-245121-A-8.wav successfully.
# Resampled 1-245609-A-2.wav successfully.
# Resampled 1-248409-A-9.wav successfully.
# Resampled 1-250623-A-9.wav successfully.
# Resampled 1-25216-A-2.wav successfully.
# Resampled 1-255828-A-6.wav successfully.
# Resampled 1-25825-A-1.wav successfully.
# Resampled 1-264641-A-9.wav successfully.
# Resampled 1-269158-A-5.wav successfully.
# Resampled 1-269774-A-4.wav successfully.
# Resampled 1-272560-A-4.wav successfully.
# Resampled 1-277430-A-4.wav successfully.
# Resampled 1-28300-A-5.wav successfully.
# Resampled 1-285983-A-8.wav successfully.
# Resampled 1-286665-A-7.wav successfully.
# Resampled 1-286813-A-0.wav successfully.
# Resampled 1-286897-A-0.wav successfully.
# Resampled 1-287220-A-3.wav successfully.
# Resampled 1-287240-A-4.wav successfully.
# Resampled 1-289501-A-3.wav successfully.
# Resampled 1-292722-A-3.wav successfully.
# Resampled 1-29601-A-3.wav successfully.
# Resampled 1-298146-A-1.wav successfully.
# Resampled 1-299158-A-2.wav successfully.
# Resampled 1-304778-A-4.wav successfully.
# Resampled 1-305863-A-8.wav successfully.
# Resampled 1-307924-A-5.wav successfully.
# Resampled 1-309545-A-5.wav successfully.
# Resampled 1-322193-A-8.wav successfully.
# Resampled 1-325264-A-2.wav successfully.
# Resampled 1-327538-A-6.wav successfully.
# Resampled 1-329265-A-1.wav successfully.
# Resampled 1-331091-A-0.wav successfully.
# Resampled 1-332804-A-1.wav successfully.
# Resampled 1-334378-A-8.wav successfully.
# Resampled 1-339730-A-9.wav successfully.
# Resampled 1-34037-A-6.wav successfully.
# Resampled 1-340396-A-3.wav successfully.
# Resampled 1-34273-A-2.wav successfully.
# Resampled 1-346109-A-0.wav successfully.
# Resampled 1-346595-A-1.wav successfully.
# Resampled 1-347670-A-7.wav successfully.
# Resampled 1-349424-A-0.wav successfully.
# Resampled 1-350852-A-2.wav successfully.
# Resampled 1-35228-A-0.wav successfully.
# Resampled 1-352876-A-6.wav successfully.
# Resampled 1-354022-A-3.wav successfully.
# Resampled 1-354538-A-2.wav successfully.
# Resampled 1-357135-A-0.wav successfully.
# Resampled 1-357197-A-5.wav successfully.
# Resampled 1-360238-A-9.wav successfully.
# Resampled 1-365582-A-2.wav successfully.
# Resampled 1-368479-A-3.wav successfully.
# Resampled 1-371325-A-7.wav successfully.
# Resampled 1-382786-A-0.wav successfully.
# Resampled 1-385023-A-5.wav successfully.
# Resampled 1-385563-A-7.wav successfully.
# Resampled 1-38722-A-1.wav successfully.
# Resampled 1-393275-A-7.wav successfully.
# Resampled 1-393311-A-9.wav successfully.
# Resampled 1-395381-A-5.wav successfully.
# Resampled 1-395713-A-3.wav successfully.
# Resampled 1-398297-A-9.wav successfully.
# Resampled 1-404103-A-9.wav successfully.
# Resampled 1-406642-A-4.wav successfully.
# Resampled 1-410303-A-1.wav successfully.
# Resampled 1-411522-A-0.wav successfully.
# Resampled 1-413642-A-3.wav successfully.
# Resampled 1-415019-A-4.wav successfully.
# Resampled 1-41563-A-2.wav successfully.
# Resampled 1-420320-A-0.wav successfully.
# Resampled 1-424030-A-4.wav successfully.
# Resampled 1-427501-A-8.wav successfully.
# Resampled 1-428569-A-4.wav successfully.
# Resampled 1-433669-A-1.wav successfully.
# Resampled 1-437070-A-8.wav successfully.
# Resampled 1-443740-A-7.wav successfully.
# Resampled 1-449068-A-5.wav successfully.
# Resampled 1-450721-A-5.wav successfully.
# Resampled 1-451441-A-9.wav successfully.
# Resampled 1-452539-A-4.wav successfully.
# Resampled 1-458078-A-0.wav successfully.
# Resampled 1-458785-A-9.wav successfully.
# Resampled 1-463051-A-2.wav successfully.
# Resampled 1-46691-A-2.wav successfully.
# Resampled 1-468053-A-1.wav successfully.
# Resampled 1-468352-A-1.wav successfully.
# Resampled 1-468356-A-8.wav successfully.
# Resampled 1-471266-A-5.wav successfully.
# Resampled 1-471719-A-7.wav successfully.
# Resampled 1-479937-A-1.wav successfully.
# Resampled 1-481637-A-7.wav successfully.
# Resampled 1-484401-A-6.wav successfully.
# Resampled 1-485604-A-5.wav successfully.
# Resampled 1-486328-A-0.wav successfully.
# Resampled 1-486926-A-8.wav successfully.
# Resampled 1-488616-A-8.wav successfully.
# Resampled 1-48866-A-8.wav successfully.
# Resampled 1-489196-A-0.wav successfully.
# Resampled 1-489964-A-2.wav successfully.
# Resampled 1-491130-A-6.wav successfully.
# Resampled 1-491974-A-2.wav successfully.
# Resampled 1-501873-A-6.wav successfully.
# Resampled 1-502985-A-6.wav successfully.
# Resampled 1-505987-A-8.wav successfully.
# Resampled 1-506154-A-6.wav successfully.
# Resampled 1-507768-A-3.wav successfully.
# Resampled 1-512226-A-5.wav successfully.
# Resampled 1-512411-A-2.wav successfully.
# Resampled 1-51359-A-7.wav successfully.
# Resampled 1-514386-A-9.wav successfully.
# Resampled 1-51879-A-5.wav successfully.
# Resampled 1-518826-A-3.wav successfully.
# Resampled 1-519629-A-7.wav successfully.
# Resampled 1-519958-A-0.wav successfully.
# Resampled 1-520014-A-8.wav successfully.
# Resampled 1-523245-A-9.wav successfully.
# Resampled 1-523924-A-7.wav successfully.
# Resampled 1-525327-A-9.wav successfully.
# Resampled 1-525944-A-1.wav successfully.
# Resampled 1-528436-A-4.wav successfully.
# Resampled 1-533056-A-4.wav successfully.
# Resampled 1-534625-A-3.wav successfully.
# Resampled 1-536442-A-7.wav successfully.
# Resampled 1-540959-A-0.wav successfully.
# Resampled 1-541582-A-6.wav successfully.
# Resampled 1-545783-A-5.wav successfully.
# Resampled 1-548807-A-0.wav successfully.
# Resampled 1-549126-A-5.wav successfully.
# Resampled 1-55059-A-0.wav successfully.
# Resampled 1-552269-A-3.wav successfully.
# Resampled 1-553438-A-3.wav successfully.
# Resampled 1-55590-A-9.wav successfully.
# Resampled 1-558694-A-0.wav successfully.
# Resampled 1-558975-A-1.wav successfully.
# Resampled 1-55953-A-9.wav successfully.
# Resampled 1-565116-A-2.wav successfully.
# Resampled 1-565823-A-8.wav successfully.
# Resampled 1-568145-A-5.wav successfully.
# Resampled 1-569819-A-1.wav successfully.
# Resampled 1-570017-A-6.wav successfully.
# Resampled 1-570547-A-1.wav successfully.
# Resampled 1-572176-A-4.wav successfully.
# Resampled 1-57395-A-3.wav successfully.
# Resampled 1-575278-A-2.wav successfully.
# Resampled 1-584016-A-2.wav successfully.
# Resampled 1-584246-A-1.wav successfully.
# Resampled 1-586628-A-2.wav successfully.
# Resampled 1-58764-A-4.wav successfully.
# Resampled 1-588959-A-3.wav successfully.
# Resampled 1-591138-A-3.wav successfully.
# Resampled 1-591151-A-7.wav successfully.
# Resampled 1-59154-A-7.wav successfully.
# Resampled 1-59284-A-6.wav successfully.
# Resampled 1-594544-A-4.wav successfully.
# Resampled 1-601270-A-9.wav successfully.
# Resampled 1-603477-A-9.wav successfully.
# Resampled 1-606060-A-1.wav successfully.
# Resampled 1-606300-A-8.wav successfully.
# Resampled 1-607453-A-1.wav successfully.
# Resampled 1-611870-A-5.wav successfully.
# Resampled 1-616179-A-6.wav successfully.
# Resampled 1-616651-A-7.wav successfully.
# Resampled 1-617345-A-4.wav successfully.
# Resampled 1-617735-A-6.wav successfully.
# Resampled 1-619113-A-6.wav successfully.
# Resampled 1-62415-A-6.wav successfully.
# Resampled 1-624367-A-3.wav successfully.
# Resampled 1-625018-A-7.wav successfully.
# Resampled 1-62729-A-0.wav successfully.
# Resampled 1-627348-A-2.wav successfully.
# Resampled 1-629240-A-8.wav successfully.
# Resampled 1-636300-A-8.wav successfully.
# Resampled 1-637692-A-2.wav successfully.
# Resampled 1-640904-A-6.wav successfully.
# Resampled 1-647441-A-9.wav successfully.
# Resampled 1-651237-A-9.wav successfully.
# Resampled 1-651452-A-8.wav successfully.
# Resampled 1-652107-A-6.wav successfully.
# Resampled 1-652257-A-0.wav successfully.
# Resampled 1-653038-A-1.wav successfully.
# Resampled 1-657875-A-7.wav successfully.
# Resampled 1-671435-A-8.wav successfully.
# Resampled 1-672158-A-5.wav successfully.
# Resampled 1-673486-A-5.wav successfully.
# Resampled 1-674556-A-1.wav successfully.
# Resampled 1-676501-A-2.wav successfully.
# Resampled 1-678545-A-0.wav successfully.
# Resampled 1-683749-A-8.wav successfully.
# Resampled 1-68577-A-7.wav successfully.
# Resampled 1-687726-A-9.wav successfully.
# Resampled 1-689625-A-4.wav successfully.
# Resampled 1-690846-A-8.wav successfully.
# Resampled 1-693179-A-4.wav successfully.
# Resampled 1-694286-A-8.wav successfully.
# Resampled 1-697233-A-6.wav successfully.
# Resampled 1-702529-A-2.wav successfully.
# Resampled 1-706055-A-9.wav successfully.
# Resampled 1-714925-A-0.wav successfully.
# Resampled 1-721947-A-7.wav successfully.
# Resampled 1-723775-A-1.wav successfully.
# Resampled 1-724077-A-1.wav successfully.
# Resampled 1-733613-A-7.wav successfully.
# Resampled 1-736405-A-8.wav successfully.
# Resampled 1-741218-A-9.wav successfully.
# Resampled 1-743675-A-3.wav successfully.
# Resampled 1-753324-A-2.wav successfully.
# Resampled 1-759762-A-4.wav successfully.
# Resampled 1-763584-A-6.wav successfully.
# Resampled 1-764806-A-2.wav successfully.
# Resampled 1-766090-A-7.wav successfully.
# Resampled 1-767432-A-2.wav successfully.
# Resampled 1-768054-A-3.wav successfully.
# Resampled 1-771620-A-8.wav successfully.
# Resampled 1-771810-A-1.wav successfully.
# Resampled 1-774296-A-2.wav successfully.
# Resampled 1-774425-A-1.wav successfully.
# Resampled 1-775146-A-0.wav successfully.
# Resampled 1-775883-A-6.wav successfully.
# Resampled 1-779917-A-3.wav successfully.
# Resampled 1-785799-A-0.wav successfully.
# Resampled 1-785963-A-5.wav successfully.
# Resampled 1-786278-A-8.wav successfully.
# Resampled 1-787047-A-7.wav successfully.
# Resampled 1-792065-A-4.wav successfully.
# Resampled 1-792169-A-9.wav successfully.
# Resampled 1-79245-A-3.wav successfully.
# Resampled 1-793209-A-3.wav successfully.
# Resampled 1-794631-A-8.wav successfully.
# Resampled 1-798199-A-8.wav successfully.
# Resampled 1-801664-A-8.wav successfully.
# Resampled 1-802764-A-2.wav successfully.
# Resampled 1-804801-A-9.wav successfully.
# Resampled 1-807344-A-4.wav successfully.
# Resampled 1-810095-A-7.wav successfully.
# Resampled 1-810832-A-5.wav successfully.
# Resampled 1-812939-A-5.wav successfully.
# Resampled 1-814376-A-8.wav successfully.
# Resampled 1-814775-A-0.wav successfully.
# Resampled 1-816327-A-7.wav successfully.
# Resampled 1-818203-A-3.wav successfully.
# Resampled 1-81882-A-4.wav successfully.
# Resampled 1-821037-A-4.wav successfully.
# Resampled 1-82322-A-9.wav successfully.
# Resampled 1-828436-A-0.wav successfully.
# Resampled 1-830427-A-9.wav successfully.
# Resampled 1-832455-A-2.wav successfully.
# Resampled 1-835008-A-6.wav successfully.
# Resampled 1-835339-A-2.wav successfully.
# Resampled 1-84003-A-1.wav successfully.
# Resampled 1-845614-A-8.wav successfully.
# Resampled 1-845900-A-7.wav successfully.
# Resampled 1-846646-A-3.wav successfully.
# Resampled 1-847358-A-9.wav successfully.
# Resampled 1-847411-A-9.wav successfully.
# Resampled 1-847603-A-0.wav successfully.
# Resampled 1-851203-A-4.wav successfully.
# Resampled 1-851807-A-4.wav successfully.
# Resampled 1-853480-A-4.wav successfully.
# Resampled 1-853499-A-4.wav successfully.
# Resampled 1-857900-A-4.wav successfully.
# Resampled 1-860441-A-5.wav successfully.
# Resampled 1-862505-A-4.wav successfully.
# Resampled 1-864178-A-7.wav successfully.
# Resampled 1-867469-A-6.wav successfully.
# Resampled 1-869977-A-1.wav successfully.
# Resampled 1-872546-A-6.wav successfully.
# Resampled 1-872607-A-5.wav successfully.
# Resampled 1-883547-A-1.wav successfully.
# Resampled 1-885269-A-7.wav successfully.
# Resampled 1-886797-A-3.wav successfully.
# Resampled 1-886888-A-0.wav successfully.
# Resampled 1-887211-A-6.wav successfully.
# Resampled 1-887638-A-7.wav successfully.
# Resampled 1-889460-A-9.wav successfully.
# Resampled 1-891832-A-6.wav successfully.
# Resampled 1-894351-A-1.wav successfully.
# Resampled 1-894522-A-4.wav successfully.
# Resampled 1-89625-A-3.wav successfully.
# Resampled 1-900035-A-2.wav successfully.
# Resampled 1-900296-A-7.wav successfully.
# Resampled 1-900649-A-2.wav successfully.
# Resampled 1-905034-A-3.wav successfully.
# Resampled 1-908858-A-3.wav successfully.
# Resampled 1-910311-A-4.wav successfully.
# Resampled 1-912733-A-0.wav successfully.
# Resampled 1-914692-A-8.wav successfully.
# Resampled 1-916827-A-5.wav successfully.
# Resampled 1-921349-A-5.wav successfully.
# Resampled 1-924649-A-8.wav successfully.
# Resampled 1-931285-A-5.wav successfully.
# Resampled 1-932445-A-3.wav successfully.
# Resampled 1-93459-A-3.wav successfully.
# Resampled 1-936804-A-2.wav successfully.
# Resampled 1-936815-A-6.wav successfully.
# Resampled 1-942355-A-4.wav successfully.
# Resampled 1-944159-A-0.wav successfully.
# Resampled 1-944459-A-8.wav successfully.
# Resampled 1-948387-A-3.wav successfully.
# Resampled 1-951768-A-8.wav successfully.
# Resampled 1-95226-A-0.wav successfully.
# Resampled 1-955509-A-1.wav successfully.
# Resampled 1-955556-A-9.wav successfully.
# Resampled 1-961162-A-4.wav successfully.
# Resampled 1-962856-A-3.wav successfully.
# Resampled 1-963126-A-6.wav successfully.
# Resampled 1-963930-A-5.wav successfully.
# Resampled 1-964874-A-2.wav successfully.
# Resampled 1-968568-A-1.wav successfully.
# Resampled 1-970607-A-5.wav successfully.
# Resampled 1-972728-A-2.wav successfully.
# Resampled 1-972863-A-8.wav successfully.
# Resampled 1-972879-A-9.wav successfully.
# Resampled 1-973417-A-7.wav successfully.
# Resampled 1-977217-A-5.wav successfully.
# Resampled 1-977509-A-3.wav successfully.
# Resampled 1-979392-A-2.wav successfully.
# Resampled 1-979832-A-0.wav successfully.
# Resampled 1-982617-A-7.wav successfully.
# Resampled 1-98369-A-1.wav successfully.
# Resampled 1-985599-A-4.wav successfully.
# Resampled 1-988331-A-9.wav successfully.
# Resampled 1-989004-A-1.wav successfully.
# Resampled 1-989080-A-0.wav successfully.
# Resampled 1-99445-A-2.wav successfully.
# Resampled 1-995090-A-9.wav successfully.
# Resampled 1-996235-A-6.wav successfully.
# Resampled 2-107859-A-5.wav successfully.
# Resampled 2-11212-A-4.wav successfully.
# Resampled 2-113544-A-9.wav successfully.
# Resampled 2-118262-A-5.wav successfully.
# Resampled 2-118737-A-0.wav successfully.
# Resampled 2-119303-A-8.wav successfully.
# Resampled 2-120257-A-9.wav successfully.
# Resampled 2-120680-A-7.wav successfully.
# Resampled 2-12234-A-8.wav successfully.
# Resampled 2-124600-A-0.wav successfully.
# Resampled 2-126530-A-5.wav successfully.
# Resampled 2-133093-A-5.wav successfully.
# Resampled 2-134521-A-7.wav successfully.
# Resampled 2-136392-A-3.wav successfully.
# Resampled 2-140505-A-6.wav successfully.
# Resampled 2-140511-A-0.wav successfully.
# Resampled 2-141044-A-3.wav successfully.
# Resampled 2-145913-A-5.wav successfully.
# Resampled 2-148188-A-2.wav successfully.
# Resampled 2-148330-A-9.wav successfully.
# Resampled 2-148354-A-8.wav successfully.
# Resampled 2-151972-A-2.wav successfully.
# Resampled 2-15221-A-4.wav successfully.
# Resampled 2-152273-A-8.wav successfully.
# Resampled 2-153509-A-9.wav successfully.
# Resampled 2-155943-A-0.wav successfully.
# Resampled 2-156236-A-0.wav successfully.
# Resampled 2-156276-A-3.wav successfully.
# Resampled 2-157300-A-1.wav successfully.
# Resampled 2-157384-A-0.wav successfully.
# Resampled 2-157835-A-5.wav successfully.
# Resampled 2-158407-A-4.wav successfully.
# Resampled 2-159167-A-1.wav successfully.
# Resampled 2-160849-A-2.wav successfully.
# Resampled 2-161166-A-0.wav successfully.
# Resampled 2-162333-A-8.wav successfully.
# Resampled 2-164855-A-3.wav successfully.
# Resampled 2-167442-A-3.wav successfully.
# Resampled 2-168096-A-7.wav successfully.
# Resampled 2-169435-A-2.wav successfully.
# Resampled 2-172010-A-6.wav successfully.
# Resampled 2-173803-A-6.wav successfully.
# Resampled 2-176540-A-3.wav successfully.
# Resampled 2-17888-A-3.wav successfully.
# Resampled 2-182109-A-3.wav successfully.
# Resampled 2-187092-A-3.wav successfully.
# Resampled 2-193175-A-9.wav successfully.
# Resampled 2-19318-A-4.wav successfully.
# Resampled 2-193660-A-4.wav successfully.
# Resampled 2-194452-A-9.wav successfully.
# Resampled 2-199372-A-1.wav successfully.
# Resampled 2-200554-A-6.wav successfully.
# Resampled 2-201998-A-2.wav successfully.
# Resampled 2-204136-A-2.wav successfully.
# Resampled 2-205908-A-5.wav successfully.
# Resampled 2-206225-A-9.wav successfully.
# Resampled 2-206854-A-9.wav successfully.
# Resampled 2-208627-A-4.wav successfully.
# Resampled 2-209326-A-6.wav successfully.
# Resampled 2-209567-A-2.wav successfully.
# Resampled 2-211119-A-8.wav successfully.
# Resampled 2-212646-A-8.wav successfully.
# Resampled 2-213352-A-4.wav successfully.
# Resampled 2-219280-A-2.wav successfully.
# Resampled 2-226378-A-5.wav successfully.
# Resampled 2-226901-A-5.wav successfully.
# Resampled 2-229642-A-2.wav successfully.
# Resampled 2-229834-A-4.wav successfully.
# Resampled 2-232140-A-6.wav successfully.
# Resampled 2-232600-A-8.wav successfully.
# Resampled 2-23398-A-6.wav successfully.
# Resampled 2-235105-A-2.wav successfully.
# Resampled 2-236694-A-6.wav successfully.
# Resampled 2-241819-A-2.wav successfully.
# Resampled 2-242887-A-7.wav successfully.
# Resampled 2-245248-A-3.wav successfully.
# Resampled 2-249468-A-2.wav successfully.
# Resampled 2-255341-A-6.wav successfully.
# Resampled 2-256648-A-5.wav successfully.
# Resampled 2-258766-A-4.wav successfully.
# Resampled 2-259731-A-8.wav successfully.
# Resampled 2-264026-A-2.wav successfully.
# Resampled 2-264367-A-8.wav successfully.
# Resampled 2-267338-A-2.wav successfully.
# Resampled 2-27049-A-8.wav successfully.
# Resampled 2-273804-A-8.wav successfully.
# Resampled 2-278541-A-8.wav successfully.
# Resampled 2-284067-A-4.wav successfully.
# Resampled 2-284724-A-0.wav successfully.
# Resampled 2-287556-A-8.wav successfully.
# Resampled 2-289269-A-9.wav successfully.
# Resampled 2-298795-A-7.wav successfully.
# Resampled 2-309129-A-4.wav successfully.
# Resampled 2-309914-A-1.wav successfully.
# Resampled 2-314312-A-2.wav successfully.
# Resampled 2-314984-A-1.wav successfully.
# Resampled 2-317529-A-3.wav successfully.
# Resampled 2-321472-A-3.wav successfully.
# Resampled 2-323407-A-1.wav successfully.
# Resampled 2-325096-A-3.wav successfully.
# Resampled 2-328752-A-4.wav successfully.
# Resampled 2-329581-A-8.wav successfully.
# Resampled 2-331592-A-3.wav successfully.
# Resampled 2-33163-A-3.wav successfully.
# Resampled 2-332570-A-6.wav successfully.
# Resampled 2-334128-A-0.wav successfully.
# Resampled 2-336322-A-9.wav successfully.
# Resampled 2-336720-A-6.wav successfully.
# Resampled 2-339913-A-1.wav successfully.
# Resampled 2-342961-A-7.wav successfully.
# Resampled 2-350450-A-7.wav successfully.
# Resampled 2-352385-A-8.wav successfully.
# Resampled 2-355556-A-6.wav successfully.
# Resampled 2-357132-A-3.wav successfully.
# Resampled 2-360076-A-7.wav successfully.
# Resampled 2-362740-A-5.wav successfully.
# Resampled 2-365047-A-9.wav successfully.
# Resampled 2-368350-A-5.wav successfully.
# Resampled 2-371513-A-2.wav successfully.
# Resampled 2-373638-A-3.wav successfully.
# Resampled 2-373947-A-5.wav successfully.
# Resampled 2-374337-A-4.wav successfully.
# Resampled 2-374390-A-6.wav successfully.
# Resampled 2-377923-A-3.wav successfully.
# Resampled 2-378244-A-9.wav successfully.
# Resampled 2-38218-A-3.wav successfully.
# Resampled 2-38357-A-3.wav successfully.
# Resampled 2-38757-A-9.wav successfully.
# Resampled 2-388033-A-8.wav successfully.
# Resampled 2-388267-A-9.wav successfully.
# Resampled 2-389697-A-0.wav successfully.
# Resampled 2-397952-A-4.wav successfully.
# Resampled 2-402976-A-0.wav successfully.
# Resampled 2-403367-A-2.wav successfully.
# Resampled 2-404110-A-8.wav successfully.
# Resampled 2-404806-A-0.wav successfully.
# Resampled 2-406558-A-6.wav successfully.
# Resampled 2-408187-A-3.wav successfully.
# Resampled 2-410361-A-0.wav successfully.
# Resampled 2-418216-A-0.wav successfully.
# Resampled 2-421307-A-3.wav successfully.
# Resampled 2-422224-A-2.wav successfully.
# Resampled 2-425059-A-0.wav successfully.
# Resampled 2-426249-A-6.wav successfully.
# Resampled 2-430189-A-4.wav successfully.
# Resampled 2-434389-A-3.wav successfully.
# Resampled 2-436232-A-9.wav successfully.
# Resampled 2-438436-A-6.wav successfully.
# Resampled 2-443242-A-9.wav successfully.
# Resampled 2-448549-A-0.wav successfully.
# Resampled 2-450005-A-1.wav successfully.
# Resampled 2-45487-A-9.wav successfully.
# Resampled 2-455680-A-2.wav successfully.
# Resampled 2-455975-A-1.wav successfully.
# Resampled 2-456677-A-5.wav successfully.
# Resampled 2-45737-A-7.wav successfully.
# Resampled 2-46013-A-2.wav successfully.
# Resampled 2-464550-A-8.wav successfully.
# Resampled 2-469007-A-9.wav successfully.
# Resampled 2-471498-A-1.wav successfully.
# Resampled 2-474779-A-1.wav successfully.
# Resampled 2-474981-A-8.wav successfully.
# Resampled 2-477108-A-3.wav successfully.
# Resampled 2-48101-A-1.wav successfully.
# Resampled 2-487193-A-6.wav successfully.
# Resampled 2-488931-A-7.wav successfully.
# Resampled 2-490698-A-2.wav successfully.
# Resampled 2-490741-A-3.wav successfully.
# Resampled 2-491335-A-0.wav successfully.
# Resampled 2-495601-A-1.wav successfully.
# Resampled 2-496454-A-3.wav successfully.
# Resampled 2-497660-A-8.wav successfully.
# Resampled 2-500831-A-9.wav successfully.
# Resampled 2-503106-A-2.wav successfully.
# Resampled 2-508623-A-4.wav successfully.
# Resampled 2-509466-A-6.wav successfully.
# Resampled 2-509795-A-5.wav successfully.
# Resampled 2-511717-A-5.wav successfully.
# Resampled 2-512285-A-7.wav successfully.
# Resampled 2-512876-A-6.wav successfully.
# Resampled 2-514163-A-1.wav successfully.
# Resampled 2-519649-A-3.wav successfully.
# Resampled 2-52396-A-6.wav successfully.
# Resampled 2-52546-A-6.wav successfully.
# Resampled 2-527953-A-2.wav successfully.
# Resampled 2-530149-A-8.wav successfully.
# Resampled 2-530248-A-9.wav successfully.
# Resampled 2-533933-A-5.wav successfully.
# Resampled 2-53653-A-6.wav successfully.
# Resampled 2-542345-A-8.wav successfully.
# Resampled 2-543371-A-0.wav successfully.
# Resampled 2-547848-A-1.wav successfully.
# Resampled 2-549834-A-4.wav successfully.
# Resampled 2-552124-A-5.wav successfully.
# Resampled 2-552669-A-5.wav successfully.
# Resampled 2-552758-A-6.wav successfully.
# Resampled 2-555741-A-4.wav successfully.
# Resampled 2-556929-A-1.wav successfully.
# Resampled 2-557219-A-0.wav successfully.
# Resampled 2-558035-A-8.wav successfully.
# Resampled 2-559037-A-7.wav successfully.
# Resampled 2-560882-A-4.wav successfully.
# Resampled 2-562249-A-0.wav successfully.
# Resampled 2-563151-A-7.wav successfully.
# Resampled 2-568505-A-5.wav successfully.
# Resampled 2-568749-A-3.wav successfully.
# Resampled 2-578269-A-7.wav successfully.
# Resampled 2-578647-A-8.wav successfully.
# Resampled 2-580654-A-1.wav successfully.
# Resampled 2-584187-A-2.wav successfully.
# Resampled 2-585898-A-9.wav successfully.
# Resampled 2-586707-A-8.wav successfully.
# Resampled 2-587091-A-2.wav successfully.
# Resampled 2-590714-A-4.wav successfully.
# Resampled 2-590786-A-5.wav successfully.
# Resampled 2-593079-A-1.wav successfully.
# Resampled 2-600133-A-9.wav successfully.
# Resampled 2-600493-A-8.wav successfully.
# Resampled 2-600611-A-1.wav successfully.
# Resampled 2-600924-A-5.wav successfully.
# Resampled 2-601373-A-0.wav successfully.
# Resampled 2-604863-A-6.wav successfully.
# Resampled 2-605932-A-9.wav successfully.
# Resampled 2-606199-A-3.wav successfully.
# Resampled 2-609900-A-4.wav successfully.
# Resampled 2-61297-A-0.wav successfully.
# Resampled 2-613271-A-5.wav successfully.
# Resampled 2-613871-A-0.wav successfully.
# Resampled 2-621767-A-6.wav successfully.
# Resampled 2-623833-A-1.wav successfully.
# Resampled 2-627687-A-9.wav successfully.
# Resampled 2-629166-A-0.wav successfully.
# Resampled 2-632426-A-6.wav successfully.
# Resampled 2-63267-A-3.wav successfully.
# Resampled 2-633032-A-9.wav successfully.
# Resampled 2-63459-A-1.wav successfully.
# Resampled 2-635988-A-9.wav successfully.
# Resampled 2-636349-A-2.wav successfully.
# Resampled 2-636568-A-5.wav successfully.
# Resampled 2-638155-A-2.wav successfully.
# Resampled 2-638343-A-2.wav successfully.
# Resampled 2-639715-A-5.wav successfully.
# Resampled 2-641303-A-4.wav successfully.
# Resampled 2-642667-A-9.wav successfully.
# Resampled 2-642703-A-2.wav successfully.
# Resampled 2-64685-A-7.wav successfully.
# Resampled 2-6492-A-1.wav successfully.
# Resampled 2-649542-A-9.wav successfully.
# Resampled 2-658711-A-4.wav successfully.
# Resampled 2-660787-A-1.wav successfully.
# Resampled 2-662561-A-1.wav successfully.
# Resampled 2-664867-A-0.wav successfully.
# Resampled 2-670304-A-7.wav successfully.
# Resampled 2-671181-A-4.wav successfully.
# Resampled 2-67922-A-4.wav successfully.
# Resampled 2-682947-A-8.wav successfully.
# Resampled 2-687282-A-9.wav successfully.
# Resampled 2-688459-A-1.wav successfully.
# Resampled 2-690991-A-8.wav successfully.
# Resampled 2-693284-A-2.wav successfully.
# Resampled 2-694282-A-6.wav successfully.
# Resampled 2-694776-A-4.wav successfully.
# Resampled 2-696406-A-3.wav successfully.
# Resampled 2-696792-A-7.wav successfully.
# Resampled 2-699740-A-0.wav successfully.
# Resampled 2-700995-A-5.wav successfully.
# Resampled 2-702480-A-4.wav successfully.
# Resampled 2-702951-A-3.wav successfully.
# Resampled 2-705956-A-7.wav successfully.
# Resampled 2-716206-A-3.wav successfully.
# Resampled 2-721589-A-6.wav successfully.
# Resampled 2-732917-A-5.wav successfully.
# Resampled 2-73379-A-7.wav successfully.
# Resampled 2-735247-A-3.wav successfully.
# Resampled 2-736625-A-3.wav successfully.
# Resampled 2-738397-A-0.wav successfully.
# Resampled 2-738676-A-5.wav successfully.
# Resampled 2-742366-A-1.wav successfully.
# Resampled 2-748726-A-3.wav successfully.
# Resampled 2-751523-A-7.wav successfully.
# Resampled 2-755116-A-1.wav successfully.
# Resampled 2-757138-A-2.wav successfully.
# Resampled 2-757334-A-8.wav successfully.
# Resampled 2-758219-A-2.wav successfully.
# Resampled 2-760392-A-0.wav successfully.
# Resampled 2-762316-A-2.wav successfully.
# Resampled 2-767304-A-9.wav successfully.
# Resampled 2-768412-A-7.wav successfully.
# Resampled 2-770210-A-8.wav successfully.
# Resampled 2-772788-A-4.wav successfully.
# Resampled 2-776368-A-5.wav successfully.
# Resampled 2-77803-A-9.wav successfully.
# Resampled 2-779445-A-1.wav successfully.
# Resampled 2-783484-A-1.wav successfully.
# Resampled 2-784053-A-0.wav successfully.
# Resampled 2-784615-A-3.wav successfully.
# Resampled 2-787356-A-6.wav successfully.
# Resampled 2-787750-A-7.wav successfully.
# Resampled 2-793435-A-1.wav successfully.
# Resampled 2-794582-A-2.wav successfully.
# Resampled 2-798646-A-0.wav successfully.
# Resampled 2-803293-A-1.wav successfully.
# Resampled 2-804878-A-1.wav successfully.
# Resampled 2-806681-A-3.wav successfully.
# Resampled 2-807584-A-5.wav successfully.
# Resampled 2-808878-A-7.wav successfully.
# Resampled 2-81059-A-0.wav successfully.
# Resampled 2-811362-A-9.wav successfully.
# Resampled 2-81504-A-8.wav successfully.
# Resampled 2-816061-A-9.wav successfully.
# Resampled 2-8166-A-6.wav successfully.
# Resampled 2-817676-A-4.wav successfully.
# Resampled 2-817848-A-1.wav successfully.
# Resampled 2-82036-A-4.wav successfully.
# Resampled 2-820978-A-0.wav successfully.
# Resampled 2-823423-A-9.wav successfully.
# Resampled 2-824946-A-5.wav successfully.
# Resampled 2-828290-A-1.wav successfully.
# Resampled 2-832113-A-5.wav successfully.
# Resampled 2-833512-A-0.wav successfully.
# Resampled 2-836972-A-8.wav successfully.
# Resampled 2-837439-A-1.wav successfully.
# Resampled 2-837464-A-6.wav successfully.
# Resampled 2-838389-A-8.wav successfully.
# Resampled 2-838696-A-4.wav successfully.
# Resampled 2-839888-A-7.wav successfully.
# Resampled 2-840153-A-7.wav successfully.
# Resampled 2-84198-A-0.wav successfully.
# Resampled 2-842665-A-4.wav successfully.
# Resampled 2-843159-A-2.wav successfully.
# Resampled 2-844336-A-8.wav successfully.
# Resampled 2-845688-A-1.wav successfully.
# Resampled 2-847635-A-5.wav successfully.
# Resampled 2-847940-A-4.wav successfully.
# Resampled 2-848699-A-2.wav successfully.
# Resampled 2-860104-A-4.wav successfully.
# Resampled 2-862788-A-5.wav successfully.
# Resampled 2-864057-A-5.wav successfully.
# Resampled 2-86571-A-9.wav successfully.
# Resampled 2-868046-A-9.wav successfully.
# Resampled 2-872663-A-8.wav successfully.
# Resampled 2-879519-A-4.wav successfully.
# Resampled 2-88009-A-9.wav successfully.
# Resampled 2-880700-A-2.wav successfully.
# Resampled 2-883688-A-0.wav successfully.
# Resampled 2-887832-A-1.wav successfully.
# Resampled 2-89039-A-0.wav successfully.
# Resampled 2-892376-A-0.wav successfully.
# Resampled 2-893154-A-9.wav successfully.
# Resampled 2-895347-A-7.wav successfully.
# Resampled 2-895413-A-4.wav successfully.
# Resampled 2-905606-A-5.wav successfully.
# Resampled 2-909347-A-4.wav successfully.
# Resampled 2-909700-A-5.wav successfully.
# Resampled 2-913603-A-7.wav successfully.
# Resampled 2-913743-A-8.wav successfully.
# Resampled 2-914257-A-5.wav successfully.
# Resampled 2-914396-A-3.wav successfully.
# Resampled 2-915176-A-8.wav successfully.
# Resampled 2-916710-A-7.wav successfully.
# Resampled 2-919440-A-1.wav successfully.
# Resampled 2-921648-A-0.wav successfully.
# Resampled 2-925273-A-6.wav successfully.
# Resampled 2-927321-A-7.wav successfully.
# Resampled 2-928479-A-4.wav successfully.
# Resampled 2-932875-A-7.wav successfully.
# Resampled 2-933062-A-8.wav successfully.
# Resampled 2-933937-A-7.wav successfully.
# Resampled 2-936394-A-3.wav successfully.
# Resampled 2-937057-A-7.wav successfully.
# Resampled 2-938176-A-2.wav successfully.
# Resampled 2-939797-A-6.wav successfully.
# Resampled 2-9424-A-2.wav successfully.
# Resampled 2-946613-A-0.wav successfully.
# Resampled 2-948837-A-6.wav successfully.
# Resampled 2-951481-A-4.wav successfully.
# Resampled 2-953721-A-7.wav successfully.
# Resampled 2-960841-A-7.wav successfully.
# Resampled 2-962478-A-7.wav successfully.
# Resampled 2-96325-A-4.wav successfully.
# Resampled 2-963322-A-1.wav successfully.
# Resampled 2-964013-A-6.wav successfully.
# Resampled 2-967512-A-6.wav successfully.
# Resampled 2-968057-A-8.wav successfully.
# Resampled 2-968166-A-6.wav successfully.
# Resampled 2-971106-A-2.wav successfully.
# Resampled 2-971750-A-7.wav successfully.
# Resampled 2-973094-A-9.wav successfully.
# Resampled 2-977592-A-0.wav successfully.
# Resampled 2-979091-A-7.wav successfully.
# Resampled 2-981291-A-5.wav successfully.
# Resampled 2-983013-A-6.wav successfully.
# Resampled 2-984014-A-1.wav successfully.
# Resampled 2-98681-A-7.wav successfully.
# Resampled 2-986837-A-9.wav successfully.
# Resampled 2-987322-A-6.wav successfully.
# Resampled 2-987965-A-6.wav successfully.
# Resampled 2-988596-A-5.wav successfully.
# Resampled 2-990320-A-7.wav successfully.
# Resampled 2-997199-A-7.wav successfully.
# Resampled 3-103487-A-7.wav successfully.
# Resampled 3-103835-A-6.wav successfully.
# Resampled 3-106150-A-6.wav successfully.
# Resampled 3-11002-A-7.wav successfully.
# Resampled 3-113722-A-8.wav successfully.
# Resampled 3-119043-A-4.wav successfully.
# Resampled 3-123983-A-4.wav successfully.
# Resampled 3-126423-A-2.wav successfully.
# Resampled 3-127665-A-1.wav successfully.
# Resampled 3-128256-A-8.wav successfully.
# Resampled 3-134288-A-4.wav successfully.
# Resampled 3-134471-A-7.wav successfully.
# Resampled 3-134899-A-6.wav successfully.
# Resampled 3-140447-A-9.wav successfully.
# Resampled 3-140885-A-2.wav successfully.
# Resampled 3-141800-A-0.wav successfully.
# Resampled 3-142591-A-2.wav successfully.
# Resampled 3-142722-A-6.wav successfully.
# Resampled 3-143759-A-1.wav successfully.
# Resampled 3-14604-A-2.wav successfully.
# Resampled 3-148506-A-2.wav successfully.
# Resampled 3-15014-A-9.wav successfully.
# Resampled 3-150378-A-7.wav successfully.
# Resampled 3-151336-A-1.wav successfully.
# Resampled 3-151600-A-8.wav successfully.
# Resampled 3-152536-A-3.wav successfully.
# Resampled 3-158216-A-9.wav successfully.
# Resampled 3-159025-A-1.wav successfully.
# Resampled 3-159906-A-8.wav successfully.
# Resampled 3-164683-A-2.wav successfully.
# Resampled 3-164705-A-4.wav successfully.
# Resampled 3-165038-A-3.wav successfully.
# Resampled 3-170320-A-1.wav successfully.
# Resampled 3-172325-A-6.wav successfully.
# Resampled 3-174345-A-6.wav successfully.
# Resampled 3-175943-A-4.wav successfully.
# Resampled 3-178276-A-0.wav successfully.
# Resampled 3-178367-A-0.wav successfully.
# Resampled 3-182351-A-0.wav successfully.
# Resampled 3-183961-A-0.wav successfully.
# Resampled 3-18615-A-0.wav successfully.
# Resampled 3-187640-A-2.wav successfully.
# Resampled 3-192029-A-6.wav successfully.
# Resampled 3-193658-A-8.wav successfully.
# Resampled 3-194004-A-5.wav successfully.
# Resampled 3-199823-A-1.wav successfully.
# Resampled 3-203654-A-3.wav successfully.
# Resampled 3-206440-A-6.wav successfully.
# Resampled 3-211853-A-8.wav successfully.
# Resampled 3-211935-A-7.wav successfully.
# Resampled 3-214804-A-9.wav successfully.
# Resampled 3-218059-A-3.wav successfully.
# Resampled 3-225050-A-8.wav successfully.
# Resampled 3-225195-A-6.wav successfully.
# Resampled 3-225323-A-2.wav successfully.
# Resampled 3-225648-A-3.wav successfully.
# Resampled 3-225768-A-0.wav successfully.
# Resampled 3-22737-A-3.wav successfully.
# Resampled 3-227436-A-5.wav successfully.
# Resampled 3-230020-A-9.wav successfully.
# Resampled 3-230237-A-4.wav successfully.
# Resampled 3-231730-A-0.wav successfully.
# Resampled 3-232265-A-1.wav successfully.
# Resampled 3-232775-A-6.wav successfully.
# Resampled 3-237432-A-9.wav successfully.
# Resampled 3-239576-A-3.wav successfully.
# Resampled 3-241921-A-7.wav successfully.
# Resampled 3-242411-A-4.wav successfully.
# Resampled 3-242687-A-5.wav successfully.
# Resampled 3-243005-A-6.wav successfully.
# Resampled 3-247612-A-6.wav successfully.
# Resampled 3-251568-A-2.wav successfully.
# Resampled 3-251968-A-2.wav successfully.
# Resampled 3-252391-A-8.wav successfully.
# Resampled 3-258536-A-1.wav successfully.
# Resampled 3-260104-A-7.wav successfully.
# Resampled 3-261315-A-0.wav successfully.
# Resampled 3-265419-A-1.wav successfully.
# Resampled 3-26650-A-6.wav successfully.
# Resampled 3-270544-A-5.wav successfully.
# Resampled 3-27445-A-1.wav successfully.
# Resampled 3-276652-A-7.wav successfully.
# Resampled 3-279722-A-0.wav successfully.
# Resampled 3-28015-A-3.wav successfully.
# Resampled 3-282113-A-5.wav successfully.
# Resampled 3-286006-A-7.wav successfully.
# Resampled 3-288854-A-3.wav successfully.
# Resampled 3-29062-A-3.wav successfully.
# Resampled 3-291326-A-6.wav successfully.
# Resampled 3-292652-A-8.wav successfully.
# Resampled 3-29385-A-3.wav successfully.
# Resampled 3-296189-A-3.wav successfully.
# Resampled 3-296339-A-0.wav successfully.
# Resampled 3-29768-A-2.wav successfully.
# Resampled 3-299714-A-5.wav successfully.
# Resampled 3-302404-A-6.wav successfully.
# Resampled 3-303287-A-9.wav successfully.
# Resampled 3-306264-A-0.wav successfully.
# Resampled 3-307552-A-5.wav successfully.
# Resampled 3-307928-A-1.wav successfully.
# Resampled 3-307936-A-5.wav successfully.
# Resampled 3-310973-A-7.wav successfully.
# Resampled 3-311116-A-4.wav successfully.
# Resampled 3-311283-A-3.wav successfully.
# Resampled 3-314339-A-2.wav successfully.
# Resampled 3-320983-A-7.wav successfully.
# Resampled 3-327660-A-2.wav successfully.
# Resampled 3-328374-A-0.wav successfully.
# Resampled 3-329645-A-8.wav successfully.
# Resampled 3-332606-A-9.wav successfully.
# Resampled 3-332870-A-9.wav successfully.
# Resampled 3-333103-A-3.wav successfully.
# Resampled 3-333181-A-0.wav successfully.
# Resampled 3-335177-A-9.wav successfully.
# Resampled 3-335808-A-2.wav successfully.
# Resampled 3-336087-A-9.wav successfully.
# Resampled 3-34243-A-2.wav successfully.
# Resampled 3-345024-A-0.wav successfully.
# Resampled 3-351073-A-0.wav successfully.
# Resampled 3-354305-A-8.wav successfully.
# Resampled 3-356765-A-2.wav successfully.
# Resampled 3-359050-A-4.wav successfully.
# Resampled 3-36017-A-2.wav successfully.
# Resampled 3-362953-A-5.wav successfully.
# Resampled 3-364907-A-9.wav successfully.
# Resampled 3-366489-A-5.wav successfully.
# Resampled 3-373534-A-8.wav successfully.
# Resampled 3-375190-A-8.wav successfully.
# Resampled 3-375444-A-6.wav successfully.
# Resampled 3-376463-A-2.wav successfully.
# Resampled 3-377019-A-3.wav successfully.
# Resampled 3-377583-A-4.wav successfully.
# Resampled 3-384242-A-2.wav successfully.
# Resampled 3-388372-A-4.wav successfully.
# Resampled 3-388601-A-4.wav successfully.
# Resampled 3-389764-A-8.wav successfully.
# Resampled 3-395429-A-1.wav successfully.
# Resampled 3-396589-A-1.wav successfully.
# Resampled 3-407973-A-6.wav successfully.
# Resampled 3-4092-A-6.wav successfully.
# Resampled 3-413579-A-5.wav successfully.
# Resampled 3-414138-A-6.wav successfully.
# Resampled 3-415289-A-7.wav successfully.
# Resampled 3-415896-A-2.wav successfully.
# Resampled 3-420088-A-3.wav successfully.
# Resampled 3-420667-A-7.wav successfully.
# Resampled 3-423804-A-4.wav successfully.
# Resampled 3-427310-A-7.wav successfully.
# Resampled 3-428088-A-7.wav successfully.
# Resampled 3-431212-A-0.wav successfully.
# Resampled 3-432089-A-5.wav successfully.
# Resampled 3-432476-A-9.wav successfully.
# Resampled 3-435474-A-3.wav successfully.
# Resampled 3-441873-A-3.wav successfully.
# Resampled 3-442272-A-7.wav successfully.
# Resampled 3-445575-A-1.wav successfully.
# Resampled 3-446402-A-0.wav successfully.
# Resampled 3-447901-A-6.wav successfully.
# Resampled 3-447977-A-4.wav successfully.
# Resampled 3-450469-A-7.wav successfully.
# Resampled 3-452336-A-1.wav successfully.
# Resampled 3-453124-A-2.wav successfully.
# Resampled 3-453246-A-1.wav successfully.
# Resampled 3-453886-A-4.wav successfully.
# Resampled 3-455725-A-8.wav successfully.
# Resampled 3-456034-A-2.wav successfully.
# Resampled 3-456562-A-1.wav successfully.
# Resampled 3-45718-A-1.wav successfully.
# Resampled 3-459996-A-4.wav successfully.
# Resampled 3-461879-A-5.wav successfully.
# Resampled 3-462095-A-0.wav successfully.
# Resampled 3-465641-A-6.wav successfully.
# Resampled 3-465926-A-3.wav successfully.
# Resampled 3-469807-A-2.wav successfully.
# Resampled 3-472114-A-7.wav successfully.
# Resampled 3-472451-A-9.wav successfully.
# Resampled 3-475373-A-9.wav successfully.
# Resampled 3-481507-A-5.wav successfully.
# Resampled 3-482135-A-5.wav successfully.
# Resampled 3-483430-A-8.wav successfully.
# Resampled 3-483911-A-5.wav successfully.
# Resampled 3-48455-A-1.wav successfully.
# Resampled 3-490436-A-4.wav successfully.
# Resampled 3-497696-A-6.wav successfully.
# Resampled 3-498737-A-3.wav successfully.
# Resampled 3-503021-A-1.wav successfully.
# Resampled 3-505890-A-5.wav successfully.
# Resampled 3-509835-A-9.wav successfully.
# Resampled 3-513188-A-4.wav successfully.
# Resampled 3-514361-A-3.wav successfully.
# Resampled 3-515367-A-1.wav successfully.
# Resampled 3-515443-A-9.wav successfully.
# Resampled 3-516797-A-2.wav successfully.
# Resampled 3-517369-A-4.wav successfully.
# Resampled 3-524241-A-2.wav successfully.
# Resampled 3-525430-A-2.wav successfully.
# Resampled 3-530982-A-0.wav successfully.
# Resampled 3-534283-A-6.wav successfully.
# Resampled 3-5362-A-3.wav successfully.
# Resampled 3-54453-A-8.wav successfully.
# Resampled 3-545884-A-3.wav successfully.
# Resampled 3-54591-A-8.wav successfully.
# Resampled 3-548670-A-5.wav successfully.
# Resampled 3-549615-A-9.wav successfully.
# Resampled 3-555416-A-2.wav successfully.
# Resampled 3-557280-A-7.wav successfully.
# Resampled 3-559216-A-5.wav successfully.
# Resampled 3-560946-A-0.wav successfully.
# Resampled 3-561362-A-1.wav successfully.
# Resampled 3-564482-A-9.wav successfully.
# Resampled 3-564695-A-9.wav successfully.
# Resampled 3-567366-A-2.wav successfully.
# Resampled 3-568477-A-4.wav successfully.
# Resampled 3-570173-A-8.wav successfully.
# Resampled 3-573964-A-6.wav successfully.
# Resampled 3-576846-A-6.wav successfully.
# Resampled 3-580756-A-2.wav successfully.
# Resampled 3-585859-A-7.wav successfully.
# Resampled 3-588056-A-7.wav successfully.
# Resampled 3-588677-A-5.wav successfully.
# Resampled 3-589891-A-3.wav successfully.
# Resampled 3-593739-A-8.wav successfully.
# Resampled 3-596353-A-5.wav successfully.
# Resampled 3-598703-A-8.wav successfully.
# Resampled 3-59940-A-8.wav successfully.
# Resampled 3-601315-A-4.wav successfully.
# Resampled 3-60380-A-5.wav successfully.
# Resampled 3-60624-A-8.wav successfully.
# Resampled 3-608383-A-2.wav successfully.
# Resampled 3-609356-A-8.wav successfully.
# Resampled 3-609715-A-2.wav successfully.
# Resampled 3-613509-A-7.wav successfully.
# Resampled 3-616007-A-6.wav successfully.
# Resampled 3-61775-A-0.wav successfully.
# Resampled 3-622204-A-7.wav successfully.
# Resampled 3-624975-A-8.wav successfully.
# Resampled 3-62596-A-9.wav successfully.
# Resampled 3-62768-A-0.wav successfully.
# Resampled 3-627925-A-2.wav successfully.
# Resampled 3-628746-A-8.wav successfully.
# Resampled 3-631074-A-4.wav successfully.
# Resampled 3-634105-A-7.wav successfully.
# Resampled 3-634412-A-7.wav successfully.
# Resampled 3-63756-A-0.wav successfully.
# Resampled 3-639611-A-0.wav successfully.
# Resampled 3-640089-A-2.wav successfully.
# Resampled 3-641154-A-4.wav successfully.
# Resampled 3-641345-A-8.wav successfully.
# Resampled 3-641414-A-7.wav successfully.
# Resampled 3-644921-A-3.wav successfully.
# Resampled 3-645881-A-5.wav successfully.
# Resampled 3-648726-A-5.wav successfully.
# Resampled 3-650062-A-5.wav successfully.
# Resampled 3-652920-A-4.wav successfully.
# Resampled 3-653091-A-1.wav successfully.
# Resampled 3-654138-A-6.wav successfully.
# Resampled 3-65631-A-7.wav successfully.
# Resampled 3-658006-A-4.wav successfully.
# Resampled 3-658398-A-5.wav successfully.
# Resampled 3-661969-A-6.wav successfully.
# Resampled 3-665265-A-0.wav successfully.
# Resampled 3-670065-A-4.wav successfully.
# Resampled 3-67278-A-8.wav successfully.
# Resampled 3-674161-A-1.wav successfully.
# Resampled 3-675839-A-8.wav successfully.
# Resampled 3-67612-A-7.wav successfully.
# Resampled 3-677274-A-8.wav successfully.
# Resampled 3-679168-A-3.wav successfully.
# Resampled 3-681324-A-4.wav successfully.
# Resampled 3-684161-A-5.wav successfully.
# Resampled 3-687510-A-9.wav successfully.
# Resampled 3-687631-A-0.wav successfully.
# Resampled 3-690716-A-6.wav successfully.
# Resampled 3-692522-A-3.wav successfully.
# Resampled 3-692943-A-2.wav successfully.
# Resampled 3-695792-A-0.wav successfully.
# Resampled 3-699509-A-7.wav successfully.
# Resampled 3-701906-A-4.wav successfully.
# Resampled 3-70240-A-1.wav successfully.
# Resampled 3-703368-A-1.wav successfully.
# Resampled 3-711595-A-0.wav successfully.
# Resampled 3-715424-A-0.wav successfully.
# Resampled 3-717151-A-8.wav successfully.
# Resampled 3-719959-A-7.wav successfully.
# Resampled 3-72517-A-4.wav successfully.
# Resampled 3-733907-A-6.wav successfully.
# Resampled 3-73538-A-1.wav successfully.
# Resampled 3-7380-A-1.wav successfully.
# Resampled 3-738372-A-4.wav successfully.
# Resampled 3-73921-A-3.wav successfully.
# Resampled 3-742749-A-5.wav successfully.
# Resampled 3-74384-A-4.wav successfully.
# Resampled 3-745321-A-3.wav successfully.
# Resampled 3-747662-A-6.wav successfully.
# Resampled 3-748448-A-5.wav successfully.
# Resampled 3-748551-A-7.wav successfully.
# Resampled 3-759757-A-0.wav successfully.
# Resampled 3-760942-A-9.wav successfully.
# Resampled 3-761757-A-3.wav successfully.
# Resampled 3-762929-A-8.wav successfully.
# Resampled 3-767987-A-7.wav successfully.
# Resampled 3-769853-A-9.wav successfully.
# Resampled 3-771446-A-3.wav successfully.
# Resampled 3-774098-A-0.wav successfully.
# Resampled 3-775445-A-3.wav successfully.
# Resampled 3-779162-A-9.wav successfully.
# Resampled 3-783706-A-1.wav successfully.
# Resampled 3-787887-A-5.wav successfully.
# Resampled 3-789058-A-5.wav successfully.
# Resampled 3-789522-A-4.wav successfully.
# Resampled 3-790029-A-6.wav successfully.
# Resampled 3-792624-A-8.wav successfully.
# Resampled 3-798092-A-9.wav successfully.
# Resampled 3-798882-A-1.wav successfully.
# Resampled 3-799551-A-3.wav successfully.
# Resampled 3-801849-A-4.wav successfully.
# Resampled 3-802042-A-2.wav successfully.
# Resampled 3-804436-A-0.wav successfully.
# Resampled 3-804437-A-5.wav successfully.
# Resampled 3-804961-A-5.wav successfully.
# Resampled 3-806442-A-7.wav successfully.
# Resampled 3-807366-A-9.wav successfully.
# Resampled 3-808036-A-2.wav successfully.
# Resampled 3-809654-A-0.wav successfully.
# Resampled 3-813427-A-1.wav successfully.
# Resampled 3-814287-A-2.wav successfully.
# Resampled 3-815470-A-6.wav successfully.
# Resampled 3-82150-A-2.wav successfully.
# Resampled 3-822710-A-9.wav successfully.
# Resampled 3-826591-A-1.wav successfully.
# Resampled 3-826973-A-9.wav successfully.
# Resampled 3-829774-A-5.wav successfully.
# Resampled 3-829900-A-4.wav successfully.
# Resampled 3-8325-A-3.wav successfully.
# Resampled 3-833405-A-6.wav successfully.
# Resampled 3-833810-A-9.wav successfully.
# Resampled 3-837415-A-4.wav successfully.
# Resampled 3-837446-A-6.wav successfully.
# Resampled 3-839887-A-2.wav successfully.
# Resampled 3-84109-A-4.wav successfully.
# Resampled 3-847320-A-8.wav successfully.
# Resampled 3-853382-A-9.wav successfully.
# Resampled 3-859354-A-0.wav successfully.
# Resampled 3-859425-A-4.wav successfully.
# Resampled 3-861414-A-3.wav successfully.
# Resampled 3-864658-A-3.wav successfully.
# Resampled 3-865915-A-0.wav successfully.
# Resampled 3-869110-A-7.wav successfully.
# Resampled 3-878010-A-1.wav successfully.
# Resampled 3-880207-A-7.wav successfully.
# Resampled 3-885355-A-0.wav successfully.
# Resampled 3-885706-A-1.wav successfully.
# Resampled 3-891170-A-6.wav successfully.
# Resampled 3-892464-A-4.wav successfully.
# Resampled 3-89732-A-5.wav successfully.
# Resampled 3-902305-A-0.wav successfully.
# Resampled 3-902375-A-7.wav successfully.
# Resampled 3-907136-A-9.wav successfully.
# Resampled 3-908160-A-6.wav successfully.
# Resampled 3-909440-A-6.wav successfully.
# Resampled 3-915603-A-2.wav successfully.
# Resampled 3-916973-A-8.wav successfully.
# Resampled 3-923883-A-3.wav successfully.
# Resampled 3-925057-A-1.wav successfully.
# Resampled 3-925447-A-7.wav successfully.
# Resampled 3-925943-A-3.wav successfully.
# Resampled 3-929998-A-7.wav successfully.
# Resampled 3-932360-A-9.wav successfully.
# Resampled 3-939767-A-9.wav successfully.
# Resampled 3-939913-A-6.wav successfully.
# Resampled 3-940473-A-7.wav successfully.
# Resampled 3-942969-A-5.wav successfully.
# ...
# Resampled 5-126432-A-5.wav successfully.
# Resampled 5-127045-A-5.wav successfully.
# Resampled 5-129434-A-9.wav successfully.
# Resampled 5-132582-A-6.wav successfully.
# Resampled 5-138819-A-4.wav successfully.
# Resampled 5-141315-A-2.wav successfully.
# Resampled 5-142437-A-7.wav successfully.
# Resampled 5-143949-A-2.wav successfully.
# Resampled 5-147051-A-0.wav successfully.
# Resampled 5-149491-A-4.wav successfully.
# Resampled 5-149969-A-5.wav successfully.
# Resampled 5-151980-A-7.wav successfully.
# Resampled 5-152368-A-0.wav successfully.
# Resampled 5-155076-A-3.wav successfully.
# Resampled 5-1560-A-3.wav successfully.
# Resampled 5-157578-A-0.wav successfully.
# Resampled 5-157693-A-4.wav successfully.
# Resampled 5-158150-A-0.wav successfully.
# Resampled 5-158677-A-1.wav successfully.
# Resampled 5-16026-A-8.wav successfully.
# Resampled 5-164409-A-6.wav successfully.
# Resampled 5-165074-A-4.wav successfully.
# Resampled 5-168067-A-6.wav successfully.
# Resampled 5-168846-A-5.wav successfully.
# Resampled 5-169622-A-1.wav successfully.
# Resampled 5-169994-A-2.wav successfully.
# Resampled 5-173705-A-6.wav successfully.
# Resampled 5-17556-A-2.wav successfully.
# Resampled 5-176666-A-3.wav successfully.
# Resampled 5-176797-A-5.wav successfully.
# Resampled 5-180640-A-8.wav successfully.
# Resampled 5-18154-A-5.wav successfully.
# Resampled 5-183200-A-6.wav successfully.
# Resampled 5-185218-A-8.wav successfully.
# Resampled 5-186633-A-4.wav successfully.
# Resampled 5-188370-A-9.wav successfully.
# Resampled 5-190455-A-3.wav successfully.
# Resampled 5-19186-A-1.wav successfully.
# Resampled 5-194214-A-8.wav successfully.
# Resampled 5-198987-A-8.wav successfully.
# Resampled 5-200462-A-2.wav successfully.
# Resampled 5-201909-A-8.wav successfully.
# Resampled 5-201926-A-9.wav successfully.
# Resampled 5-204371-A-5.wav successfully.
# Resampled 5-214861-A-0.wav successfully.
# Resampled 5-224687-A-9.wav successfully.
# Resampled 5-226450-A-4.wav successfully.
# Resampled 5-236601-A-2.wav successfully.
# Resampled 5-24779-A-6.wav successfully.
# Resampled 5-248298-A-2.wav successfully.
# Resampled 5-25059-A-0.wav successfully.
# Resampled 5-251176-A-4.wav successfully.
# Resampled 5-252080-A-0.wav successfully.
# Resampled 5-252239-A-2.wav successfully.
# Resampled 5-252614-A-1.wav successfully.
# Resampled 5-252769-A-7.wav successfully.
# Resampled 5-253598-A-8.wav successfully.
# Resampled 5-254234-A-0.wav successfully.
# Resampled 5-254424-A-0.wav successfully.
# Resampled 5-254591-A-9.wav successfully.
# Resampled 5-257027-A-3.wav successfully.
# Resampled 5-258792-A-2.wav successfully.
# Resampled 5-260454-A-1.wav successfully.
# Resampled 5-261886-A-3.wav successfully.
# Resampled 5-263670-A-4.wav successfully.
# Resampled 5-270472-A-9.wav successfully.
# Resampled 5-271575-A-2.wav successfully.
# Resampled 5-274057-A-6.wav successfully.
# Resampled 5-27636-A-5.wav successfully.
# Resampled 5-280688-A-0.wav successfully.
# Resampled 5-286569-A-6.wav successfully.
# Resampled 5-289505-A-6.wav successfully.
# Resampled 5-29293-A-2.wav successfully.
# Resampled 5-294682-A-1.wav successfully.
# Resampled 5-297469-A-1.wav successfully.
# Resampled 5-299273-A-3.wav successfully.
# Resampled 5-30046-A-0.wav successfully.
# Resampled 5-303000-A-9.wav successfully.
# Resampled 5-305219-A-5.wav successfully.
# Resampled 5-305559-A-8.wav successfully.
# Resampled 5-308394-A-0.wav successfully.
# Resampled 5-312650-A-0.wav successfully.
# Resampled 5-32564-A-3.wav successfully.
# Resampled 5-326528-A-4.wav successfully.
# Resampled 5-328296-A-4.wav successfully.
# Resampled 5-335148-A-3.wav successfully.
# Resampled 5-337448-A-7.wav successfully.
# Resampled 5-33982-A-0.wav successfully.
# Resampled 5-340345-A-4.wav successfully.
# Resampled 5-341466-A-7.wav successfully.
# Resampled 5-341887-A-4.wav successfully.
# Resampled 5-342879-A-3.wav successfully.
# Resampled 5-34479-A-6.wav successfully.
# Resampled 5-345360-A-8.wav successfully.
# Resampled 5-345728-A-3.wav successfully.
# Resampled 5-345960-A-6.wav successfully.
# Resampled 5-346940-A-2.wav successfully.
# Resampled 5-355328-A-4.wav successfully.
# Resampled 5-355561-A-6.wav successfully.
# Resampled 5-357472-A-6.wav successfully.
# Resampled 5-363314-A-3.wav successfully.
# Resampled 5-365605-A-2.wav successfully.
# Resampled 5-368089-A-2.wav successfully.
# Resampled 5-37289-A-9.wav successfully.
# Resampled 5-378098-A-2.wav successfully.
# Resampled 5-37935-A-5.wav successfully.
# Resampled 5-382973-A-4.wav successfully.
# Resampled 5-384370-A-8.wav successfully.
# Resampled 5-386771-A-5.wav successfully.
# Resampled 5-387113-A-2.wav successfully.
# Resampled 5-3941-A-4.wav successfully.
# Resampled 5-396629-A-9.wav successfully.
# Resampled 5-404819-A-7.wav successfully.
# Resampled 5-405658-A-7.wav successfully.
# Resampled 5-409230-A-7.wav successfully.
# Resampled 5-409661-A-9.wav successfully.
# Resampled 5-411184-A-8.wav successfully.
# Resampled 5-414018-A-7.wav successfully.
# Resampled 5-414868-A-7.wav successfully.
# Resampled 5-415509-A-8.wav successfully.
# Resampled 5-416305-A-7.wav successfully.
# Resampled 5-420113-A-5.wav successfully.
# Resampled 5-421250-A-6.wav successfully.
# Resampled 5-421557-A-6.wav successfully.
# Resampled 5-422159-A-1.wav successfully.
# Resampled 5-422729-A-8.wav successfully.
# Resampled 5-426224-A-6.wav successfully.
# Resampled 5-42650-A-5.wav successfully.
# Resampled 5-42745-A-2.wav successfully.
# Resampled 5-434996-A-8.wav successfully.
# Resampled 5-44383-A-5.wav successfully.
# Resampled 5-444933-A-1.wav successfully.
# Resampled 5-45178-A-1.wav successfully.
# Resampled 5-452323-A-9.wav successfully.
# Resampled 5-45352-A-4.wav successfully.
# Resampled 5-457099-A-7.wav successfully.
# Resampled 5-458576-A-9.wav successfully.
# Resampled 5-460441-A-3.wav successfully.
# Resampled 5-471604-A-2.wav successfully.
# Resampled 5-473766-A-6.wav successfully.
# Resampled 5-473910-A-7.wav successfully.
# Resampled 5-475671-A-0.wav successfully.
# Resampled 5-480866-A-4.wav successfully.
# Resampled 5-480917-A-8.wav successfully.
# Resampled 5-483250-A-1.wav successfully.
# Resampled 5-486871-A-7.wav successfully.
# Resampled 5-492178-A-9.wav successfully.
# Resampled 5-493485-A-7.wav successfully.
# Resampled 5-494393-A-6.wav successfully.
# Resampled 5-496301-A-3.wav successfully.
# Resampled 5-498506-A-2.wav successfully.
# Resampled 5-500283-A-9.wav successfully.
# Resampled 5-501053-A-2.wav successfully.
# Resampled 5-503664-A-0.wav successfully.
# Resampled 5-505883-A-1.wav successfully.
# Resampled 5-506025-A-0.wav successfully.
# Resampled 5-507932-A-4.wav successfully.
# Resampled 5-508581-A-4.wav successfully.
# Resampled 5-511079-A-2.wav successfully.
# Resampled 5-511654-A-4.wav successfully.
# Resampled 5-511813-A-7.wav successfully.
# Resampled 5-515572-A-3.wav successfully.
# Resampled 5-522667-A-2.wav successfully.
# Resampled 5-522723-A-9.wav successfully.
# Resampled 5-523515-A-4.wav successfully.
# Resampled 5-524020-A-2.wav successfully.
# Resampled 5-524220-A-8.wav successfully.
# Resampled 5-525201-A-6.wav successfully.
# Resampled 5-529140-A-1.wav successfully.
# Resampled 5-531544-A-6.wav successfully.
# Resampled 5-532955-A-3.wav successfully.
# Resampled 5-534092-A-8.wav successfully.
# Resampled 5-534527-A-7.wav successfully.
# Resampled 5-541416-A-5.wav successfully.
# Resampled 5-543912-A-0.wav successfully.
# Resampled 5-544616-A-2.wav successfully.
# Resampled 5-54515-A-1.wav successfully.
# Resampled 5-546311-A-8.wav successfully.
# Resampled 5-547397-A-9.wav successfully.
# Resampled 5-54840-A-9.wav successfully.
# Resampled 5-548486-A-7.wav successfully.
# Resampled 5-550429-A-1.wav successfully.
# Resampled 5-550756-A-5.wav successfully.
# Resampled 5-552218-A-3.wav successfully.
# Resampled 5-55420-A-3.wav successfully.
# Resampled 5-555524-A-5.wav successfully.
# Resampled 5-556635-A-8.wav successfully.
# Resampled 5-558215-A-2.wav successfully.
# Resampled 5-560431-A-7.wav successfully.
# Resampled 5-561256-A-4.wav successfully.
# Resampled 5-567095-A-1.wav successfully.
# Resampled 5-57038-A-1.wav successfully.
# Resampled 5-57340-A-9.wav successfully.
# Resampled 5-574860-A-0.wav successfully.
# Resampled 5-576106-A-6.wav successfully.
# Resampled 5-579307-A-3.wav successfully.
# Resampled 5-579349-A-1.wav successfully.
# Resampled 5-582429-A-6.wav successfully.
# Resampled 5-58366-A-1.wav successfully.
# Resampled 5-584697-A-3.wav successfully.
# Resampled 5-585538-A-7.wav successfully.
# Resampled 5-585727-A-0.wav successfully.
# Resampled 5-588598-A-7.wav successfully.
# Resampled 5-595224-A-2.wav successfully.
# Resampled 5-596408-A-8.wav successfully.
# Resampled 5-598679-A-0.wav successfully.
# Resampled 5-599746-A-4.wav successfully.
# Resampled 5-60107-A-0.wav successfully.
# Resampled 5-60529-A-8.wav successfully.
# Resampled 5-607423-A-4.wav successfully.
# Resampled 5-611149-A-5.wav successfully.
# Resampled 5-614438-A-5.wav successfully.
# Resampled 5-61495-A-9.wav successfully.
# Resampled 5-617247-A-4.wav successfully.
# Resampled 5-617714-A-9.wav successfully.
# Resampled 5-618489-A-2.wav successfully.
# Resampled 5-619607-A-1.wav successfully.
# Resampled 5-621278-A-3.wav successfully.
# Resampled 5-621706-A-1.wav successfully.
# Resampled 5-623760-A-0.wav successfully.
# Resampled 5-625092-A-9.wav successfully.
# Resampled 5-625868-A-6.wav successfully.
# Resampled 5-626425-A-7.wav successfully.
# Resampled 5-630825-A-3.wav successfully.
# Resampled 5-631101-A-6.wav successfully.
# Resampled 5-63146-A-0.wav successfully.
# Resampled 5-632655-A-8.wav successfully.
# Resampled 5-634160-A-7.wav successfully.
# Resampled 5-642434-A-9.wav successfully.
# Resampled 5-642776-A-8.wav successfully.
# Resampled 5-644515-A-4.wav successfully.
# Resampled 5-646543-A-1.wav successfully.
# Resampled 5-648186-A-9.wav successfully.
# Resampled 5-652140-A-5.wav successfully.
# Resampled 5-654495-A-5.wav successfully.
# Resampled 5-654812-A-5.wav successfully.
# Resampled 5-656150-A-6.wav successfully.
# Resampled 5-659881-A-7.wav successfully.
# Resampled 5-661249-A-6.wav successfully.
# Resampled 5-664162-A-9.wav successfully.
# Resampled 5-667786-A-5.wav successfully.
# Resampled 5-668341-A-2.wav successfully.
# Resampled 5-668407-A-1.wav successfully.
# Resampled 5-671349-A-7.wav successfully.
# Resampled 5-673139-A-3.wav successfully.
# Resampled 5-674888-A-4.wav successfully.
# Resampled 5-678126-A-6.wav successfully.
# Resampled 5-682940-A-6.wav successfully.
# Resampled 5-685250-A-0.wav successfully.
# Resampled 5-690454-A-3.wav successfully.
# Resampled 5-693731-A-4.wav successfully.
# Resampled 5-694624-A-6.wav successfully.
# Resampled 5-697134-A-8.wav successfully.
# Resampled 5-699326-A-9.wav successfully.
# Resampled 5-701470-A-7.wav successfully.
# Resampled 5-702100-A-9.wav successfully.
# Resampled 5-706293-A-2.wav successfully.
# Resampled 5-708940-A-6.wav successfully.
# Resampled 5-713689-A-9.wav successfully.
# Resampled 5-7213-A-4.wav successfully.
# Resampled 5-723842-A-6.wav successfully.
# Resampled 5-729547-A-9.wav successfully.
# Resampled 5-729724-A-3.wav successfully.
# Resampled 5-730523-A-8.wav successfully.
# Resampled 5-731486-A-2.wav successfully.
# Resampled 5-731502-A-9.wav successfully.
# Resampled 5-731719-A-9.wav successfully.
# Resampled 5-733164-A-3.wav successfully.
# Resampled 5-734139-A-7.wav successfully.
# Resampled 5-735366-A-3.wav successfully.
# Resampled 5-736527-A-3.wav successfully.
# Resampled 5-738416-A-1.wav successfully.
# Resampled 5-747515-A-0.wav successfully.
# Resampled 5-750975-A-7.wav successfully.
# Resampled 5-767306-A-5.wav successfully.
# Resampled 5-769776-A-9.wav successfully.
# Resampled 5-770958-A-7.wav successfully.
# Resampled 5-772090-A-7.wav successfully.
# Resampled 5-77470-A-3.wav successfully.
# Resampled 5-777901-A-5.wav successfully.
# Resampled 5-778180-A-7.wav successfully.
# Resampled 5-778428-A-2.wav successfully.
# Resampled 5-77896-A-8.wav successfully.
# Resampled 5-785456-A-7.wav successfully.
# Resampled 5-787885-A-4.wav successfully.
# Resampled 5-793135-A-6.wav successfully.
# Resampled 5-793420-A-6.wav successfully.
# Resampled 5-794097-A-3.wav successfully.
# Resampled 5-79742-A-5.wav successfully.
# Resampled 5-799144-A-8.wav successfully.
# Resampled 5-799257-A-8.wav successfully.
# Resampled 5-799271-A-2.wav successfully.
# Resampled 5-79947-A-1.wav successfully.
# Resampled 5-799922-A-3.wav successfully.
# Resampled 5-800864-A-9.wav successfully.
# Resampled 5-802974-A-0.wav successfully.
# Resampled 5-803305-A-9.wav successfully.
# Resampled 5-803675-A-3.wav successfully.
# Resampled 5-807030-A-1.wav successfully.
# Resampled 5-807902-A-4.wav successfully.
# Resampled 5-809287-A-0.wav successfully.
# Resampled 5-809773-A-5.wav successfully.
# Resampled 5-811855-A-1.wav successfully.
# Resampled 5-813125-A-4.wav successfully.
# Resampled 5-814098-A-4.wav successfully.
# Resampled 5-814920-A-5.wav successfully.
# Resampled 5-818677-A-5.wav successfully.
# Resampled 5-821524-A-3.wav successfully.
# Resampled 5-823049-A-1.wav successfully.
# Resampled 5-823990-A-3.wav successfully.
# Resampled 5-825788-A-0.wav successfully.
# Resampled 5-82733-A-4.wav successfully.
# Resampled 5-828338-A-3.wav successfully.
# Resampled 5-82879-A-5.wav successfully.
# Resampled 5-830091-A-7.wav successfully.
# Resampled 5-830464-A-1.wav successfully.
# Resampled 5-836071-A-8.wav successfully.
# Resampled 5-838277-A-0.wav successfully.
# Resampled 5-838733-A-9.wav successfully.
# Resampled 5-83899-A-1.wav successfully.
# Resampled 5-841263-A-3.wav successfully.
# Resampled 5-843413-A-5.wav successfully.
# Resampled 5-843914-A-6.wav successfully.
# Resampled 5-846572-A-5.wav successfully.
# Resampled 5-849215-A-9.wav successfully.
# Resampled 5-850705-A-8.wav successfully.
# Resampled 5-855289-A-5.wav successfully.
# Resampled 5-855556-A-4.wav successfully.
# Resampled 5-874684-A-5.wav successfully.
# Resampled 5-875739-A-2.wav successfully.
# Resampled 5-876771-A-1.wav successfully.
# Resampled 5-877327-A-0.wav successfully.
# Resampled 5-880737-A-6.wav successfully.
# Resampled 5-881749-A-2.wav successfully.
# Resampled 5-888798-A-0.wav successfully.
# Resampled 5-892685-A-1.wav successfully.
# Resampled 5-893928-A-7.wav successfully.
# Resampled 5-899074-A-0.wav successfully.
# Resampled 5-89936-A-2.wav successfully.
# Resampled 5-903066-A-7.wav successfully.
# Resampled 5-905866-A-6.wav successfully.
# Resampled 5-906934-A-8.wav successfully.
# Resampled 5-907951-A-5.wav successfully.
# Resampled 5-91121-A-6.wav successfully.
# Resampled 5-918820-A-1.wav successfully.
# Resampled 5-921563-A-6.wav successfully.
# Resampled 5-922530-A-9.wav successfully.
# Resampled 5-924905-A-0.wav successfully.
# Resampled 5-929932-A-1.wav successfully.
# Resampled 5-9311-A-7.wav successfully.
# Resampled 5-940618-A-5.wav successfully.
# Resampled 5-94138-A-6.wav successfully.
# Resampled 5-941428-A-0.wav successfully.
# Resampled 5-94365-A-2.wav successfully.
# Resampled 5-944698-A-4.wav successfully.
# Resampled 5-945805-A-7.wav successfully.
# Resampled 5-947852-A-8.wav successfully.
# Resampled 5-948708-A-0.wav successfully.
# Resampled 5-951998-A-8.wav successfully.
# Resampled 5-952299-A-5.wav successfully.
# Resampled 5-952823-A-9.wav successfully.
# Resampled 5-953745-A-1.wav successfully.
# Resampled 5-95507-A-1.wav successfully.
# Resampled 5-957060-A-7.wav successfully.
# Resampled 5-957637-A-2.wav successfully.
# Resampled 5-958537-A-2.wav successfully.
# Resampled 5-960301-A-3.wav successfully.
# Resampled 5-962428-A-7.wav successfully.
# Resampled 5-967975-A-8.wav successfully.
# Resampled 5-970830-A-1.wav successfully.
# Resampled 5-972566-A-3.wav successfully.
# Resampled 5-973496-A-7.wav successfully.
# Resampled 5-974399-A-8.wav successfully.
# Resampled 5-978159-A-9.wav successfully.
# Resampled 5-979965-A-5.wav successfully.
# Resampled 5-981886-A-9.wav successfully.
# Resampled 5-985817-A-2.wav successfully.
# Resampled 5-98688-A-8.wav successfully.
# Resampled 5-988233-A-8.wav successfully.
# Resampled 5-991680-A-0.wav successfully.
# Resampled 5-993251-A-4.wav successfully.
# Resampled 5-994030-A-8.wav successfully.
# Resampled 5-994158-A-5.wav successfully.
# Resampled 5-995395-A-1.wav successfully.
# Resampled 5-996625-A-3.wav successfully.
# Resampled 5-996779-A-9.wav successfully.
# Resampled 5-998935-A-8.wav successfully.
# Resampled 5-999956-A-5.wav successfully.
# -------------Success-------------
# -------------Build Dataset-------------
# -------------Success-------------

# %%
# Load the model package
import torch
from torch.utils.data import DataLoader
from torch.utils.data.distributed import DistributedSampler
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint

from utils import create_folder, dump_config
import esc_config as config
from sed_model import SEDWrapper
from data_generator import ESC_Dataset
from model.htsat import HTSAT_Swin_Transformer

# %%
# Data Preparation
class data_prep(pl.LightningDataModule):
    def __init__(self, train_dataset, eval_dataset, device_num):
        super().__init__()
        self.train_dataset = train_dataset
        self.eval_dataset = eval_dataset
        self.device_num = device_num

    def train_dataloader(self):
        train_sampler = DistributedSampler(self.train_dataset, shuffle = False) if self.device_num > 1 else None
        train_loader = DataLoader(
            dataset = self.train_dataset,
            num_workers = config.num_workers,
            batch_size = config.batch_size // self.device_num,
            shuffle = False,
            sampler = train_sampler
        )
        return train_loader
    def val_dataloader(self):
        eval_sampler = DistributedSampler(self.eval_dataset, shuffle = False) if self.device_num > 1 else None
        eval_loader = DataLoader(
            dataset = self.eval_dataset,
            num_workers = config.num_workers,
            batch_size = config.batch_size // self.device_num,
            shuffle = False,
            sampler = eval_sampler
        )
        return eval_loader
    def test_dataloader(self):
        test_sampler = DistributedSampler(self.eval_dataset, shuffle = False) if self.device_num > 1 else None
        test_loader = DataLoader(
            dataset = self.eval_dataset,
            num_workers = config.num_workers,
            batch_size = config.batch_size // self.device_num,
            shuffle = False,
            sampler = test_sampler
        )
        return test_loader

# %%
print(config.classes_num)
# Out:
# 10

# %%
# Set the workspace
device_num = torch.cuda.device_count()

print("Using", device_num, "GPUs")
print("each batch size:", config.batch_size // device_num)

full_dataset = np.load(os.path.join(config.dataset_path, "sonidos_peligrosos-data.npy"), allow_pickle = True)

# set exp folder
exp_dir = os.path.join(config.workspace, "results", config.exp_name)
checkpoint_dir = os.path.join(config.workspace, "results", config.exp_name, "checkpoint")
if not config.debug:
    create_folder(os.path.join(config.workspace, "results"))
    create_folder(exp_dir)
    create_folder(checkpoint_dir)
    dump_config(config, os.path.join(exp_dir, config.exp_name), False)

print("Using ESC")
dataset = ESC_Dataset(
    dataset = full_dataset,
    config = config,
    eval_mode = False
)
eval_dataset = ESC_Dataset(
    dataset = full_dataset,
    config = config,
    eval_mode = True
)

audioset_data = data_prep(dataset, eval_dataset, device_num)
checkpoint_callback = ModelCheckpoint(
    monitor = "acc",
    filename='l-{epoch:d}-{acc:.3f}',
    save_top_k = 20,
    mode = "max"
)
# Out:
# Using 1 GPUs
# each batch size: 32
# Using ESC

# %%
# Aqui en esta parte se prepara para el entrenamiento
trainer = pl.Trainer(
    deterministic=False,#para que los resultados sean reproducibles
    default_root_dir = checkpoint_dir,#ruta donde se guardan los checkpoints
    gpus = device_num, #numero de gpus
    val_check_interval = 1.0,#cada cuantas epocas se valida
    max_epochs = config.max_epoch,#numero de epocas
    auto_lr_find = True,    #para que busque el mejor learning rate
    sync_batchnorm = True, #para que sincronice el batchnorm
    callbacks = [checkpoint_callback], #para que guarde los checkpoints cada cierto tiempo
    accelerator = "ddp" if device_num > 1 else None, #para que use todas las gpus
    num_sanity_val_steps = 0, 
    resume_from_checkpoint = None, 
    replace_sampler_ddp = False,
    gradient_clip_val=1.0
)

sed_model = HTSAT_Swin_Transformer(
    spec_size=config.htsat_spec_size,
    patch_size=config.htsat_patch_size,
    in_chans=1,
    num_classes=config.classes_num,
    window_size=config.htsat_window_size,
    config = config,
    depths = config.htsat_depth,
    embed_dim = config.htsat_dim,
    patch_stride=config.htsat_stride,
    num_heads=config.htsat_num_head
)

model = SEDWrapper(
    sed_model = sed_model, 
    config = config,
    dataset = dataset
)

if config.resume_checkpoint is not None:
    print("Load Checkpoint from ", config.resume_checkpoint)
    ckpt = torch.load(config.resume_checkpoint, map_location="cpu")
    ckpt["state_dict"].pop("sed_model.head.weight")
    ckpt["state_dict"].pop("sed_model.head.bias")
    # finetune on the esc and spv2 dataset
    ckpt["state_dict"].pop("sed_model.tscam_conv.weight")
    ckpt["state_dict"].pop("sed_model.tscam_conv.bias")
    model.load_state_dict(ckpt["state_dict"], strict=False)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Load Checkpoint from  ./workspace/ckpt/htsat_audioset_pretrain.ckpt

# %%
# vaciar la memoria de la gpu
torch.cuda.empty_cache()
# Comenzar el entrenamiento
trainer.fit(model, audioset_data)

# Guardar el estado del modelo manualmente después del entrenamiento
model_path = 'modelo_entrenado/modelo_final_entrenado.ckpt'
torch.save(model.state_dict(), model_path)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                   | Params
# -----------------------------------------------------
# 0 | sed_model | HTSAT_Swin_Transformer | 28.7 M
# -----------------------------------------------------
# 27.6 M    Trainable params
# 1.1 M     Non-trainable params
# 28.7 M    Total params
# 114.657   Total estimated model params size (MB)
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_lightning\trainer\data_loading.py:132: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_lightning\trainer\data_loading.py:132: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:   0%|          | 0/63 [00:00<?, ?it/s]
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_lightning\utilities\data.py:59: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 16. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Epoch 0:  30%|███       | 19/63 [03:56<09:08, 12.46s/it, loss=2.21, v_num=4, loss_step=2.060]
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_lightning\utilities\data.py:59: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 15. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Epoch 0: 100%|██████████| 63/63 [13:06<00:00, 12.48s/it, loss=1.59, v_num=4, loss_step=1.350]cuda:0 {'acc': 0.88}
# Epoch 1: 100%|██████████| 63/63 [13:21<00:00, 12.72s/it, loss=0.0847, v_num=4, loss_step=0.0616, acc=0.880, loss_epoch=1.910]cuda:0 {'acc': 0.895}
# Epoch 2: 100%|██████████| 63/63 [13:19<00:00, 12.69s/it, loss=0.0312, v_num=4, loss_step=0.0141, acc=0.895, loss_epoch=0.370] cuda:0 {'acc': 0.8925}
# Epoch 3: 100%|██████████| 63/63 [13:47<00:00, 13.14s/it, loss=0.0057, v_num=4, loss_step=0.00386, acc=0.892, loss_epoch=0.0398] cuda:0 {'acc': 0.895}
# Epoch 4: 100%|██████████| 63/63 [13:12<00:00, 12.58s/it, loss=0.011, v_num=4, loss_step=0.00222, acc=0.895, loss_epoch=0.00627]  cuda:0 {'acc': 0.8975}
# Epoch 5: 100%|██████████| 63/63 [14:09<00:00, 13.49s/it, loss=0.00391, v_num=4, loss_step=0.00272, acc=0.897, loss_epoch=0.00947]cuda:0 {'acc': 0.9}
# Epoch 6: 100%|██████████| 63/63 [14:11<00:00, 13.51s/it, loss=0.00591, v_num=4, loss_step=0.0014, acc=0.900, loss_epoch=0.0118]  cuda:0 {'acc': 0.905}
# Epoch 7:   5%|▍         | 3/63 [00:41<13:54, 13.91s/it, loss=0.00154, v_num=4, loss_step=0.00118, acc=0.905, loss_epoch=0.00484]
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_lightning\utilities\data.py:59: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 14. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Epoch 7: 100%|██████████| 63/63 [14:00<00:00, 13.35s/it, loss=0.00199, v_num=4, loss_step=0.0168, acc=0.905, loss_epoch=0.00484]  cuda:0 {'acc': 0.905}
# Epoch 8: 100%|██████████| 63/63 [13:27<00:00, 12.81s/it, loss=0.00719, v_num=4, loss_step=0.000818, acc=0.905, loss_epoch=0.00164] cuda:0 {'acc': 0.915}
# Epoch 9: 100%|██████████| 63/63 [14:32<00:00, 13.85s/it, loss=0.029, v_num=4, loss_step=0.000682, acc=0.915, loss_epoch=0.0047]   cuda:0 {'acc': 0.885}
# Epoch 10: 100%|██████████| 63/63 [14:38<00:00, 13.94s/it, loss=0.00151, v_num=4, loss_step=0.00226, acc=0.885, loss_epoch=0.0179] cuda:0 {'acc': 0.905}
# Epoch 11: 100%|██████████| 63/63 [16:31<00:00, 15.74s/it, loss=0.000701, v_num=4, loss_step=0.000417, acc=0.905, loss_epoch=0.00526]cuda:0 {'acc': 0.8975}
# Epoch 12: 100%|██████████| 63/63 [15:27<00:00, 14.72s/it, loss=0.000645, v_num=4, loss_step=0.00063, acc=0.897, loss_epoch=0.000794] cuda:0 {'acc': 0.8975}
# Epoch 13: 100%|██████████| 63/63 [14:53<00:00, 14.18s/it, loss=0.000418, v_num=4, loss_step=0.0004, acc=0.897, loss_epoch=0.000591]  cuda:0 {'acc': 0.905}
# Epoch 14: 100%|██████████| 63/63 [15:18<00:00, 14.58s/it, loss=0.000407, v_num=4, loss_step=0.000534, acc=0.905, loss_epoch=0.000488]cuda:0 {'acc': 0.9}
# Epoch 15: 100%|██████████| 63/63 [15:23<00:00, 14.66s/it, loss=0.000737, v_num=4, loss_step=0.000378, acc=0.900, loss_epoch=0.000448]cuda:0 {'acc': 0.9025}
# Epoch 16: 100%|██████████| 63/63 [15:15<00:00, 14.54s/it, loss=0.000359, v_num=4, loss_step=0.000319, acc=0.902, loss_epoch=0.00065] cuda:0 {'acc': 0.9}
# Epoch 17: 100%|██████████| 63/63 [15:17<00:00, 14.56s/it, loss=0.000589, v_num=4, loss_step=0.000301, acc=0.900, loss_epoch=0.000426]cuda:0 {'acc': 0.8975}
# Epoch 18: 100%|██████████| 63/63 [15:16<00:00, 14.55s/it, loss=0.00036, v_num=4, loss_step=0.000467, acc=0.897, loss_epoch=0.000699] cuda:0 {'acc': 0.9025}
# Epoch 19: 100%|██████████| 63/63 [15:10<00:00, 14.46s/it, loss=0.000311, v_num=4, loss_step=0.000568, acc=0.902, loss_epoch=0.000367]cuda:0 {'acc': 0.8975}
# Epoch 20: 100%|██████████| 63/63 [15:13<00:00, 14.51s/it, loss=0.000353, v_num=4, loss_step=0.000241, acc=0.897, loss_epoch=0.000317]cuda:0 {'acc': 0.8975}
# Epoch 21: 100%|██████████| 63/63 [15:15<00:00, 14.53s/it, loss=0.000625, v_num=4, loss_step=0.000209, acc=0.897, loss_epoch=0.000303]cuda:0 {'acc': 0.8975}
# Epoch 22: 100%|██████████| 63/63 [15:56<00:00, 15.19s/it, loss=0.000246, v_num=4, loss_step=0.000391, acc=0.897, loss_epoch=0.00044] cuda:0 {'acc': 0.8975}
# Epoch 23: 100%|██████████| 63/63 [15:25<00:00, 14.70s/it, loss=0.000264, v_num=4, loss_step=0.000318, acc=0.897, loss_epoch=0.000273]cuda:0 {'acc': 0.8975}
# Epoch 24: 100%|██████████| 63/63 [15:26<00:00, 14.71s/it, loss=0.000314, v_num=4, loss_step=0.000277, acc=0.897, loss_epoch=0.000258]cuda:0 {'acc': 0.8975}
# Epoch 25: 100%|██████████| 63/63 [15:02<00:00, 14.32s/it, loss=0.000255, v_num=4, loss_step=0.000239, acc=0.897, loss_epoch=0.000311]cuda:0 {'acc': 0.8975}
# Epoch 26: 100%|██████████| 63/63 [15:17<00:00, 14.57s/it, loss=0.000236, v_num=4, loss_step=0.000245, acc=0.897, loss_epoch=0.000406]cuda:0 {'acc': 0.9}
# Epoch 27: 100%|██████████| 63/63 [15:09<00:00, 14.44s/it, loss=0.000252, v_num=4, loss_step=0.000178, acc=0.900, loss_epoch=0.00033] cuda:0 {'acc': 0.9}
# Epoch 28: 100%|██████████| 63/63 [15:57<00:00, 15.19s/it, loss=0.000287, v_num=4, loss_step=0.000202, acc=0.900, loss_epoch=0.000809]cuda:0 {'acc': 0.9}
# Epoch 29: 100%|██████████| 63/63 [15:55<00:00, 15.17s/it, loss=0.000265, v_num=4, loss_step=0.000905, acc=0.900, loss_epoch=0.000264]cuda:0 {'acc': 0.8975}
# Epoch 30: 100%|██████████| 63/63 [15:57<00:00, 15.20s/it, loss=0.000213, v_num=4, loss_step=0.000165, acc=0.897, loss_epoch=0.000312]cuda:0 {'acc': 0.9}
# Epoch 31: 100%|██████████| 63/63 [15:56<00:00, 15.18s/it, loss=0.000242, v_num=4, loss_step=0.000352, acc=0.900, loss_epoch=0.000212]cuda:0 {'acc': 0.8975}
# Epoch 32: 100%|██████████| 63/63 [15:55<00:00, 15.17s/it, loss=0.000215, v_num=4, loss_step=0.000182, acc=0.897, loss_epoch=0.000225]cuda:0 {'acc': 0.8975}
# Epoch 33: 100%|██████████| 63/63 [15:54<00:00, 15.15s/it, loss=0.000178, v_num=4, loss_step=0.000172, acc=0.897, loss_epoch=0.000203]cuda:0 {'acc': 0.8975}
# Epoch 34: 100%|██████████| 63/63 [15:56<00:00, 15.18s/it, loss=0.000167, v_num=4, loss_step=0.000161, acc=0.897, loss_epoch=0.000205]cuda:0 {'acc': 0.8975}
# Epoch 35: 100%|██████████| 63/63 [15:55<00:00, 15.17s/it, loss=0.000303, v_num=4, loss_step=0.000145, acc=0.897, loss_epoch=0.000171]cuda:0 {'acc': 0.8975}
# Epoch 36: 100%|██████████| 63/63 [15:38<00:00, 14.89s/it, loss=0.000155, v_num=4, loss_step=0.000157, acc=0.897, loss_epoch=0.000219]cuda:0 {'acc': 0.9}
# Epoch 37: 100%|██████████| 63/63 [15:27<00:00, 14.72s/it, loss=0.000193, v_num=4, loss_step=0.000123, acc=0.900, loss_epoch=0.000212]cuda:0 {'acc': 0.9}
# Epoch 38: 100%|██████████| 63/63 [15:22<00:00, 14.64s/it, loss=0.000301, v_num=4, loss_step=0.000133, acc=0.900, loss_epoch=0.00019] cuda:0 {'acc': 0.89}
# Epoch 39: 100%|██████████| 63/63 [15:24<00:00, 14.67s/it, loss=0.000158, v_num=4, loss_step=0.000254, acc=0.890, loss_epoch=0.00145]cuda:0 {'acc': 0.8975}
# Epoch 40: 100%|██████████| 63/63 [15:24<00:00, 14.67s/it, loss=0.000136, v_num=4, loss_step=0.00012, acc=0.897, loss_epoch=0.000167] cuda:0 {'acc': 0.895}
# Epoch 41: 100%|██████████| 63/63 [15:13<00:00, 14.49s/it, loss=0.000144, v_num=4, loss_step=0.000164, acc=0.895, loss_epoch=0.000264]cuda:0 {'acc': 0.895}
# Epoch 42: 100%|██████████| 63/63 [15:20<00:00, 14.61s/it, loss=0.000147, v_num=4, loss_step=0.000107, acc=0.895, loss_epoch=0.000157]cuda:0 {'acc': 0.8975}
# Epoch 43: 100%|██████████| 63/63 [15:24<00:00, 14.68s/it, loss=0.000133, v_num=4, loss_step=0.000121, acc=0.897, loss_epoch=0.000141]cuda:0 {'acc': 0.895}
# Epoch 44: 100%|██████████| 63/63 [15:18<00:00, 14.58s/it, loss=0.000141, v_num=4, loss_step=0.000121, acc=0.895, loss_epoch=0.000159]cuda:0 {'acc': 0.895}
# Epoch 45: 100%|██████████| 63/63 [15:27<00:00, 14.73s/it, loss=0.00012, v_num=4, loss_step=0.000188, acc=0.895, loss_epoch=0.000141] cuda:0 {'acc': 0.8975}
# Epoch 46: 100%|██████████| 63/63 [15:18<00:00, 14.58s/it, loss=0.000216, v_num=4, loss_step=0.000115, acc=0.897, loss_epoch=0.000122]cuda:0 {'acc': 0.8975}
# Epoch 47: 100%|██████████| 63/63 [15:21<00:00, 14.62s/it, loss=0.000132, v_num=4, loss_step=0.000205, acc=0.897, loss_epoch=0.000157]cuda:0 {'acc': 0.9}
# Epoch 48: 100%|██████████| 63/63 [15:09<00:00, 14.44s/it, loss=0.000108, v_num=4, loss_step=9.76e-5, acc=0.900, loss_epoch=0.000118] cuda:0 {'acc': 0.8975}
# Epoch 49: 100%|██████████| 63/63 [15:53<00:00, 15.14s/it, loss=0.000136, v_num=4, loss_step=0.000118, acc=0.897, loss_epoch=0.000108]cuda:0 {'acc': 0.905}
# Epoch 49: 100%|██████████| 63/63 [16:07<00:00, 15.36s/it, loss=0.000136, v_num=4, loss_step=0.000118, acc=0.905, loss_epoch=0.00178]

# %% [markdown]
# REALIZAR PREDICCIONES DE SONIDOS

# %%
# recuperar el modelo entrenado para hacer predicciones
model_path = 'workspace/results/exp_htsat_dataset_sonidos_peligrosos/checkpoint/lightning_logs/version_4/checkpoints/l-epoch=49-acc=0.905.ckpt'

meta = np.loadtxt(meta_path , delimiter=',', dtype='str', skiprows=1)
gd = {}
for label in meta:
    name = label[0]
    target = label[2]
    gd[name] = target

class Audio_Classification:
    def __init__(self, model_path, config):
        super().__init__()

        self.device = torch.device('cuda')
        self.sed_model = HTSAT_Swin_Transformer(
            spec_size=config.htsat_spec_size,
            patch_size=config.htsat_patch_size,
            in_chans=1,
            num_classes=config.classes_num,
            window_size=config.htsat_window_size,
            config = config,
            depths = config.htsat_depth,
            embed_dim = config.htsat_dim,
            patch_stride=config.htsat_stride,
            num_heads=config.htsat_num_head
        )
        ckpt = torch.load(model_path, map_location="cpu")
        temp_ckpt = {}
        for key in ckpt["state_dict"]:
            temp_ckpt[key[10:]] = ckpt['state_dict'][key]
        self.sed_model.load_state_dict(temp_ckpt)
        self.sed_model.to(self.device)
        self.sed_model.eval()


    def predict(self, audiofile):

        if audiofile:
            waveform, sr = librosa.load(audiofile, sr=32000)

            with torch.no_grad():
                x = torch.from_numpy(waveform).float().to(self.device)
                output_dict = self.sed_model(x[None, :], None, True)
                pred = output_dict['clipwise_output']
                pred_post = pred[0].detach().cpu().numpy()
                pred_label = np.argmax(pred_post)
                pred_prob = np.max(pred_post)
            return pred_label, pred_prob

# %%
# Inferencia de audio
Audiocls = Audio_Classification(model_path, config)

# realizamos la prediccion para un audio de prueba
pred_label, pred_prob = Audiocls.predict('G:/Mi unidad/DatasetAudiosPrueba/sonidos_prueba_funcionamiento/disparo.wav')

print('Audiocls predict output: ', pred_label, pred_prob)
# Out:
# Audiocls predict output:  2 10.048427
